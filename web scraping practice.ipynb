# %% [markdown]
# # Web scraping: Python

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://boston.craigslist.org/search/sof"

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.text

# %%
print(data)
# Out:
# ﻿<!DOCTYPE html>
# <html class="no-js"><head>
#     <title>boston software/qa/dba/etc  - craigslist</title>
#
#     <meta name="description" content="boston software/qa/dba/etc  - craigslist">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#     <link rel="canonical" href="https://boston.craigslist.org/search/sof">
#     <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=281764e2707bd58e05233e4b7df36df8">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=2d972697128e23b83898e73d71ad0d39">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#
#
#         <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "4";
# var areaRegion = "MA";
# var catAbb = "sof";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "jjj";
# var sectionBase = "jjj";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
#
#     <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=842da1f4e6843c73e1f537775ad18488" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
# </head>
# <body class="search has-map">
#     <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
#
#
#     <section class="page-container" id="page-top">
#         <div class="bglogo"></div>
#         <header class="global-header wide">
#    <a class="header-logo" name="logoLink" href="/">CL</a>
#
#     <nav class="breadcrumbs-container">
# <form id="breadcrumbform" class="breadcrumbs-form" method="get" action="/search/sof" data-action="/search/###/sof">
#
#     <ul class="breadcrumbs ">
#         <li class="crumb area">
#
#             <span class="no-js">
#                 <a href="/">boston</a>
#             </span>
#                 <select name="areaAbb" id="areaAbb" class="js-only">
#                     <option value="boston">boston</option>
#                         <option value="albany">albany, NY</option>
#                         <option value="capecod">cape cod</option>
#                         <option value="catskills">catskills</option>
#                         <option value="cnj">central NJ</option>
#                         <option value="newlondon">eastern CT</option>
#                         <option value="glensfalls">glens falls</option>
#                         <option value="hartford">hartford</option>
#                         <option value="hudsonvalley">hudson valley</option>
#                         <option value="jerseyshore">jersey shore</option>
#                         <option value="longisland">long island</option>
#                         <option value="maine">maine</option>
#                         <option value="nh">new hampshire</option>
#                         <option value="newhaven">new haven</option>
#                         <option value="newyork">new york</option>
#                         <option value="newjersey">north jersey</option>
#                         <option value="nwct">northwest CT</option>
#                         <option value="oneonta">oneonta</option>
#                         <option value="plattsburgh">plattsburgh</option>
#                         <option value="poconos">poconos</option>
#                         <option value="providence">rhode island</option>
#                         <option value="southcoast">south coast</option>
#                         <option value="utica">utica</option>
#                         <option value="vermont">vermont</option>
#                         <option value="westernmass">western mass</option>
#                         <option value="worcester">worcester</option>
#                 </select>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb subarea">
#             <select id="subArea" name="subArea">
#                 <option value="" selected>all boston</option>
#                 <option value="gbs">boston/camb/brook</option>
#                 <option value="bmw">metro west</option>
#                 <option value="nos">north shore</option>
#                 <option value="nwb">northwest/merrimack</option>
#                 <option value="sob">south shore</option>
#             </select>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb section">
#                     <select name="catAbb" id="catAbb">
#                         <option value="ccc">community</option>
#                         <option value="eee">events</option>
#                         <option value="sss">for sale</option>
#                         <option value="ggg">gigs</option>
#                         <option value="hhh">housing</option>
#                         <option value="jjj" selected>jobs</option>
#                         <option value="rrr">resumes</option>
#                         <option value="bbb">services</option>
#                     </select>
#                 <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb category">
#             <select id="subcatAbb" class="js-only">
#                 <option value="jjj">all</option>
#                     <option value="ofc">admin/office</option>
#                     <option value="bus">business</option>
#                     <option value="csr">customer service</option>
#                     <option value="edu">education</option>
#                     <option value="egr">engineering</option>
#                     <option value="etc">etcetera</option>
#                     <option value="acc">finance</option>
#                     <option value="fbh">food/bev/hosp</option>
#                     <option value="lab">general labor</option>
#                     <option value="gov">government</option>
#                     <option value="hea">healthcare</option>
#                     <option value="hum">human resource</option>
#                     <option value="lgl">legal</option>
#                     <option value="mnu">manufacturing</option>
#                     <option value="mar">marketing</option>
#                     <option value="med">media</option>
#                     <option value="npo">nonprofit</option>
#                     <option value="rej">real estate</option>
#                     <option value="ret">retail/wholesale</option>
#                     <option value="sls">sales</option>
#                     <option value="spa">salon/spa/fitness</option>
#                     <option value="sci">science</option>
#                     <option value="sec">security</option>
#                     <option value="trd">skilled trades</option>
#                     <option value="sof" selected>software</option>
#                     <option value="sad">systems/networking</option>
#                     <option value="tch">tech support</option>
#                     <option value="trp">transport</option>
#                     <option value="tfr">tv video radio</option>
#                     <option value="web">web design</option>
#                     <option value="wri">writing</option>
#             </select><span class="no-js">software</span>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb no-js">
#             <input type="submit" value="go">
#         </li>
#     </ul>
# </form>
#     </nav>
#
# <div class="userlinks">
#     <ul class="user-actions">
#         <li class="user post">
#             <a href="https://post.craigslist.org/c/bos">post</a>
#         </li>
#         <li class="user account">
#             <a href="https://accounts.craigslist.org/login/home">account</a>
#         </li>
#     </ul>
#     <ul class="user-favs-discards">
#         <li class="user">
#             <div class="favorites">
#                 <a href="#" class="favlink"><span class="icon icon-star fav" aria-hidden="true"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
#             </div>
#         </li>
#         <li class="user discards">
#           <form class="unfavform js-only" method="POST" action="/favorites">
#             <div class="to-banish-page">
#               <input type="hidden" class="lastLink" name="lastLink" value="//boston.craigslist.org/search/sof">
#               <input type="hidden" class="lastTitle" name="lastTitle" value="boston software/qa/dba/etc  - craigslist">
#               <input type="hidden" class="unfaves" name="fl">
#               <input type="hidden" name="uf" value="1">
#               <a href="#" class="to-banish-page-link">
#                 <span class="icon icon-trash red" aria-hidden="true"></span>
#                 <span class="banished_count">0</span>
#                 <span class="discards-label"> hidden</span>
#               </a>
#             </div>
#           </form>
#         </li>
#     </ul>
# </div>
#
# </header>
# <header class="global-header narrow">
#    <a class="header-logo" href="/">CL</a>
#     <nav class="breadcrumbs-container">
#
# <ul class="breadcrumbs">
#
#
# boston            &gt;
#
# software/qa/dba/etc
#
# </ul>
#
#
#     </nav>
#     <span class="linklike show-wide-header">...</span>
# </header>
#
#
#         <form id="searchform" class="search-form" action="/search/sof">
#             <div class="querybox">
#
#                 <div class="form-tab js-only"><span class="search-open" title="hide search">&laquo;</span><span class="search-closed" title="show search">&raquo;</span></div>
#                 <input type="text" placeholder="search software/qa/dba/etc" name="query"
#                     id="query" value="" autocorrect="off" class="flatinput ui-autocomplete-input"
#                     autocapitalize="off" autocomplete="off" data-autocomplete="search">
#
#                 <button type="submit" class="searchbtn">
#                     <span class="icon icon-search" aria-hidden="true"></span>
#                     <span class="screen-reader-text">press to search craigslist</span>
#                 </button>
#                     <div class="savealert">
#                         <a class="saveme" data-action="save"  href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fboston%252Ecraigslist%252Eorg%252Fsearch%252Fsof"  title="save this search" >save search</a>
#                     </div>
#             </div>
#
#             <div class="search-options-container">
#     <h2 class="search-options-header linklike">
#         <div class="icon icon-toggle-gear" aria-hidden="true"></div>
#         options<span class="options-close">close</span>
#     </h2>
#     <input id="excats" type="hidden" name="excats">
#     <div class="search-options">
#         <div class="searchgroup categories">
#             <div class="cattitle">
#                   <a href="/search/sof" title="clear all search parameters" class="reset">software/qa/dba/etc</a>
#             </div>
#
#         </div>
#         <input type="hidden" name="userid" value="" />
#
#
#
#
#
#         <div class="searchgroup">
#             <ul>
#     <li>
#        <label class="srchType">
#            <input type="checkbox" name="srchType" class="" value="T" >
#            search titles only
#        </label>
#     </li>
#     <li>
#        <label class="hasPic">
#            <input type="checkbox" name="hasPic" class="autosubmit" value="1" >
#            has image
#        </label>
#     </li>
#     <li>
#        <label class="postedToday">
#            <input type="checkbox" name="postedToday" class="autosubmit" value="1" >
#            posted today
#        </label>
#     </li>
#     <li>
#        <label class="bundleDuplicates">
#            <input type="checkbox" name="bundleDuplicates" class="autosubmit" value="1" >
#            bundle duplicates
#        </label>
#     </li>
#     <li>
#        <label class="searchNearby">
#            <input type="checkbox" name="searchNearby" class="autosubmit" value="1" >
#            include nearby areas
#        </label>
#     </li>
# </ul>
#
#                 <ul class="js-only nearbyAreas ">
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_10"
#                             value="59"
#                             disabled="disabled"
#                             />
#                             albany, NY <small>(alb)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_26"
#                             value="248"
#                             disabled="disabled"
#                             />
#                             binghamton, NY <small>(bgm)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_3"
#                             value="239"
#                             disabled="disabled"
#                             />
#                             cape cod / islands <small>(cap)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_14"
#                             value="451"
#                             disabled="disabled"
#                             />
#                             catskills <small>(cat)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_24"
#                             value="349"
#                             disabled="disabled"
#                             />
#                             central NJ <small>(cnj)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_4"
#                             value="281"
#                             disabled="disabled"
#                             />
#                             eastern CT <small>(nlo)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_6">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_36"
#                             value="453"
#                             disabled="disabled"
#                             />
#                             elmira-corning <small>(elm)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_35"
#                             value="685"
#                             disabled="disabled"
#                             />
#                             finger lakes, NY <small>(fgl)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_11"
#                             value="686"
#                             disabled="disabled"
#                             />
#                             glens falls, NY <small>(gfl)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_5"
#                             value="44"
#                             disabled="disabled"
#                             />
#                             hartford, CT <small>(htf)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_12"
#                             value="249"
#                             disabled="disabled"
#                             />
#                             hudson valley, NY <small>(hud)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_32"
#                             value="201"
#                             disabled="disabled"
#                             />
#                             ithaca, NY <small>(ith)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_21"
#                             value="561"
#                             disabled="disabled"
#                             />
#                             jersey shore <small>(jys)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_28"
#                             value="167"
#                             disabled="disabled"
#                             />
#                             lehigh valley <small>(alt)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_13"
#                             value="250"
#                             disabled="disabled"
#                             />
#                             long island, NY <small>(isp)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_16"
#                             value="169"
#                             disabled="disabled"
#                             />
#                             maine <small>(mne)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_6"
#                             value="198"
#                             disabled="disabled"
#                             />
#                             new hampshire <small>(nhm)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_9"
#                             value="168"
#                             disabled="disabled"
#                             />
#                             new haven, CT <small>(hvn)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_18"
#                             value="3"
#                             disabled="disabled"
#                             />
#                             new york city <small>(nyc)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_17"
#                             value="170"
#                             disabled="disabled"
#                             />
#                             north jersey <small>(njy)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_8"
#                             value="354"
#                             disabled="disabled"
#                             />
#                             northwest CT <small>(nct)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_20"
#                             value="684"
#                             disabled="disabled"
#                             />
#                             oneonta, NY <small>(onh)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_31"
#                             value="17"
#                             disabled="disabled"
#                             />
#                             philadelphia <small>(phi)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_19"
#                             value="338"
#                             disabled="disabled"
#                             />
#                             plattsburgh-adirondacks <small>(plb)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_23"
#                             value="356"
#                             disabled="disabled"
#                             />
#                             poconos <small>(poc)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_27"
#                             value="683"
#                             disabled="disabled"
#                             />
#                             potsdam-canton-massena <small>(ptd)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_34"
#                             value="278"
#                             disabled="disabled"
#                             />
#                             reading, PA <small>(rea)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_1"
#                             value="38"
#                             disabled="disabled"
#                             />
#                             rhode island <small>(prv)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_25"
#                             value="276"
#                             disabled="disabled"
#                             />
#                             scranton / wilkes-barre <small>(avp)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_2"
#                             value="378"
#                             disabled="disabled"
#                             />
#                             south coast, MA <small>(sma)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_33"
#                             value="286"
#                             disabled="disabled"
#                             />
#                             south jersey <small>(snj)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_4">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_29"
#                             value="130"
#                             disabled="disabled"
#                             />
#                             syracuse, NY <small>(syr)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_3">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_22"
#                             value="247"
#                             disabled="disabled"
#                             />
#                             utica-rome-oneida <small>(uti)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_2">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_15"
#                             value="93"
#                             disabled="disabled"
#                             />
#                             vermont <small>(brl)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_5">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_30"
#                             value="337"
#                             disabled="disabled"
#                             />
#                             watertown, NY <small>(wtn)</small>
#                         </label>
#                         </li>
#                         <li class="nearbyZone nearbyZone_1">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_7"
#                             value="173"
#                             disabled="disabled"
#                             />
#                             western massachusetts <small>(wma)</small>
#                         </label>
#                         </li>
#                         <li class="">
#                         <label class="nearby">
#                             <input
#                             type="checkbox"
#                             class="use-id nearbyArea"
#                             name="nearbyArea"
#                             id="nearbyArea_0"
#                             value="240"
#                             disabled="disabled"
#                             />
#                             worcester / central MA <small>(wor)</small>
#                         </label>
#                         </li>
#
#                         <li>
#                         <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">37</span> more...
#                         </span>
#                         </li>
#                 </ul>
#         </div>
#
#             <div class="searchgroup">
#                 <span class="searchfieldlabel">miles from zip</span>
#                 <input type="number" max="200" min="0" size="3" inputmode="numeric"
#                     class="flatinput searchInput search_distance" placeholder="miles"
#                     name="search_distance"
#                     value=""
#                 />
#                 <input type="text" class="flatinput searchInput postal" placeholder="from zip"
#                     size="7" name="postal" value="">
#                 <span class="icon icon-locate"></span>
#             </div>
#
#
#
#
#
#         <div class="searchgroup"><label class="is_internship">
#         <input type="checkbox" name="is_internship" value="1" class="autosubmit" />
#     internship
# </label><br>
# <label class="is_nonprofit">
#         <input type="checkbox" name="is_nonprofit" value="1" class="autosubmit" />
#     non-profit
# </label><br>
# <label class="is_telecommuting">
#         <input type="checkbox" name="is_telecommuting" value="1" class="autosubmit" />
#     telecommute
# </label><br>
# </div><div class="searchgroup"><div class="search-attribute " data-attr="employment_type">
#     <div class="title linklike ">
#         <span class="plus">&#9656;</span><span class="minus">&#9662;</span> employment type
#     </div>
#
#         <ul class="list">
#
#             <li class="checkbox ">
#                 <label>
#                     <input id="employment_type_1" name="employment_type" class="multi_checkbox" value="1" type="checkbox"
#                      />
#                     full-time
#                 </label>
#             </li>
#             <li class="checkbox ">
#                 <label>
#                     <input id="employment_type_2" name="employment_type" class="multi_checkbox" value="2" type="checkbox"
#                      />
#                     part-time
#                 </label>
#             </li>
#             <li class="checkbox ">
#                 <label>
#                     <input id="employment_type_3" name="employment_type" class="multi_checkbox" value="3" type="checkbox"
#                      />
#                     contract
#                 </label>
#             </li>
#             <li class="checkbox ">
#                 <label>
#                     <input id="employment_type_4" name="employment_type" class="multi_checkbox" value="4" type="checkbox"
#                      />
#                     employee's choice
#                 </label>
#             </li>
#
#
#
#     </ul>
# </div>
# </div>
#
#         <div class="searchgroup resetsearch">
#             <a href="/search/sof" title="clear all search parameters" class="reset linklike">reset</a>
#             <button type="submit" class="searchlink linklike">update search</button>
#         </div>
#
#     </div>
# </div>
#
#
#             <div class="search-legend">
# <div class="search-view js-only">
#     <div class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar" aria-label="view options" aria-expanded="false">
#         <ul class="dropdown-list">
#             <li class="dropdown-item mode sel">
#                 <button title="show results in a list" data-selection="list" id="listview">
#                     <span class="view-list icon"></span>list
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#             <li class="dropdown-item mode">
#                 <button title="show results in a list with thumbnail pictures"  data-selection="pic"  id="picview" >
#                     <span class="view-thumb icon"></span>thumb
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#             <li class="dropdown-item mode">
#                 <button title="show results side-by-side with larger pictures" data-selection="grid" id="gridview">
#                     <span class="view-gallery icon"></span>gallery
#                 </button>
#                 <span class="toggle-arrow"></span>
#             </li>
#                 <li class="dropdown-item mode">
#                     <button title="show results on a map"  data-selection="map"  id="mapview" >
#                         <span class="view-map icon"></span>map
#                     </button>
#                     <span class="toggle-arrow"></span>
#                 </li>
#         </ul>
#     </div>
# </div>
#                 <div class="search-sort" >
#     <div class="dropdown dropdown-sort " data-default-sort="date" role="toolbar" aria-label="sort options" aria-expanded="false">
#         <ul class="dropdown-list">
#
#             <li class="dropdown-item mode sel" aria-selected="true">
#                 <a data-selection="date" title="show newest matches first" href="/search/sof?sort=date&amp;">newest <span class="toggle-arrow"></span></a>
#             </li>
#
#         </ul>
#     </div>
# </div>
#
#                 <div class="paginator buttongroup firstpage lastpage">
#     <span class="resulttotal">
#         <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
#     </span>
#     <span class="buttons">
#         <a href="/search/sof" class="button first" title="first page">&lt;&lt;</a>
#         <span class="button first" title="first page">&lt;&lt;</span>
#         <a href="/search/sof" class="button prev" title="previous page">&lt; prev</a>
#         <span class="button prev" title="previous page">&lt; prev</span>
#
#         <span class="button pagenum">
#             <span class="range">
#                 <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">76</span>
#             </span>
#             /
#             <span class="totalcount">76</span>
#         </span>
#
#         <a href="" class="button next" title="next page">next &gt; </a>
#         <span class="button next" title="next page"> next &gt; </span>
#     </span>
# </div>
#
#
#             </div>
#             <div class="content" id="sortable-results" >
#                 <section class="favlistsection">
#                     <section class="favlistinfo">
#                     </section>
#                     <section class="banishlistinfo">
#                     </section>
#                 </section>
#
#
#
#
# <div class="open-map-view-button">
#     <span>see in map view</span>
# </div>
# <div id="mapcontainer" data-arealat="42.358299" data-arealon="-71.060303">
#     <div id="noresult-overlay"></div>
#     <div id="noresult-text">
#         <span class="message">No mappable items found</span>
#     </div>
#     <div id="map" class="loading">
#         <div class="close-full-screen-map-mode-button">close fullscreen</div>
#         <div class="close-map-view-button">close map</div>
#     </div>
# </div>
#
#                 <ul class="rows">
#                              <li class="result-row" data-pid="6897232058">
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html" class="result-image gallery" data-ids="1:00s0s_fVfmIfCpZqU">
#         </a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-25 14:09" title="Sat 25 May 02:09:19 PM">May 25</time>
#
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html" data-id="6897232058" class="result-title hdrlnk">Seeking iOS/Android Developer</a>
#
#
#         <span class="result-meta">
#
#
#
#                 <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6897232058">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6895801656">
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-23 15:55" title="Thu 23 May 03:55:12 PM">May 23</time>
#
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html" data-id="6895801656" class="result-title hdrlnk">Senior Enterprise Analyst</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="result-hood"> (Boston)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6895801656">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6895791557">
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-23 15:43" title="Thu 23 May 03:43:21 PM">May 23</time>
#
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html" data-id="6895791557" class="result-title hdrlnk">Cloud Engineer</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="result-hood"> (Boston)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6895791557">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6895749083">
#
#         <a href="https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-23 14:56" title="Thu 23 May 02:56:22 PM">May 23</time>
#
#
# ...
#
#
#         <span class="result-meta">
#
#
#                 <span class="result-hood"> (Newton)</span>
#
#                 <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6874340537">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#
#                     <h4 class="ban nearby"><span class="bantext">Few local results found. Here are some from nearby areas. Checking &#39;include nearby areas&#39; will expand your search.</span></h4>
#
#                              <li class="result-row" data-pid="6880467247">
#
#         <a href="https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-03 10:52" title="Fri 03 May 10:52:22 AM">May  3</time>
#
#
#         <a href="https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html" data-id="6880467247" class="result-title hdrlnk">Summer DevOps Internship</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="nearby" title="worcester / central MA">(wor &gt; Westborough,MA)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6880467247">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6889723644">
#
#         <a href="https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-15 16:29" title="Wed 15 May 04:29:55 PM">May 15</time>
#
#
#         <a href="https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html" data-id="6889723644" class="result-title hdrlnk">Data Manager</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="nearby" title="rhode island">(prv)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6889723644">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6881546089">
#
#         <a href="https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-04 16:43" title="Sat 04 May 04:43:59 PM">May  4</time>
#
#
#         <a href="https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html" data-id="6881546089" class="result-title hdrlnk">Medical Equipment Inspection, Troubleshooting and Basic Repair</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="nearby" title="south coast, MA">(sma &gt; New Bedford, MA)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6881546089">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6881861456">
#
#         <a href="https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-05-05 09:34" title="Sun 05 May 09:34:34 AM">May  5</time>
#
#
#         <a href="https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html" data-id="6881861456" class="result-title hdrlnk">Database Architect</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="nearby" title="cape cod / islands">(cap &gt; Woods Hole, MA)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6881861456">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#          <li class="result-row" data-pid="6874669025">
#
#         <a href="https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html" class="result-image gallery empty"></a>
#
#     <p class="result-info">
#         <span class="icon icon-star" role="button">
#             <span class="screen-reader-text">favorite this post</span>
#         </span>
#
#             <time class="result-date" datetime="2019-04-25 15:12" title="Thu 25 Apr 03:12:09 PM">Apr 25</time>
#
#
#         <a href="https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html" data-id="6874669025" class="result-title hdrlnk">Business Analyst - UCONN</a>
#
#
#         <span class="result-meta">
#
#
#                 <span class="nearby" title="hartford, CT">(htf &gt; Storrs, CT)</span>
#
#                 <span class="result-tags">
#                     <span class="maptag" data-pid="6874669025">map</span>
#                 </span>
#
#                 <span class="banish icon icon-trash" role="button">
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#
#             <span class="unbanish icon icon-trash red" role="button" aria-hidden="true"></span>
#             <a href="#" class="restore-link">
#                 <span class="restore-narrow-text">restore</span>
#                 <span class="restore-wide-text">restore this posting</span>
#             </a>
#
#         </span>
#     </p>
# </li>
#
#                 </ul>
#             </div>
#
#             <div class="search-legend bottom">
#                 <div class="search-view">
#                     <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#                 </div>
#                 <div class="search-sort">
#                     <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
#                 </div>
#                 <div class="paginator buttongroup firstpage lastpage">
#     <span class="resulttotal">
#         <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
#     </span>
#     <span class="buttons">
#         <a href="/search/sof" class="button first" title="first page">&lt;&lt;</a>
#         <span class="button first" title="first page">&lt;&lt;</span>
#         <a href="/search/sof" class="button prev" title="previous page">&lt; prev</a>
#         <span class="button prev" title="previous page">&lt; prev</span>
#
#         <span class="button pagenum">
#             <span class="range">
#                 <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">76</span>
#             </span>
#             /
#             <span class="totalcount">76</span>
#         </span>
#
#         <a href="" class="button next" title="next page">next &gt; </a>
#         <span class="button next" title="next page"> next &gt; </span>
#     </span>
# </div>
#
#             </div>
#
#             <section class="blurbs">
#
#             </section>
#
#             <div id="floater">
#                 <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 <img class="payload" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#             </div>
#         </form>
#
#
# <div class="slidemessage">
#     <span class="fave">
#         <span class="star"></span>
#         favorited
#     </span>
#     <span class="unfave">
#         <span class="star"></span>
#         no longer favorited
#     </span>
#     <span class="hide">
#         <span class="trash"></span>
#         hidden
#     </span>
#     <span class="unhide">
#         <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
#
# <footer>
#         <span class="rss">
#             <a class="l" href="https://boston.craigslist.org/search/sof?format=rss">RSS</a>
#             <a href="https://www.craigslist.org/about/rss">(?)</a><br>
#         </span>
#     <ul class="clfooter">
#         <li>&copy;  <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
#         <li><a href="https://www.craigslist.org/about/help/">help</a></li>
#         <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
#         <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a></li>
#         <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
#         <li class="desktop"><a href="https://www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
#         <li><a href="//www.craigslist.org/about/terms.of.use.en-us">terms</a><sup class="neu">new</sup></li>
#         <li><a href="https://www.craigslist.org/about/">about</a></li>
#         <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
#         <li class="fsel mobile linklike" data-mode="regular">desktop</li>
#     </ul>
# </footer>
#     </section>
#
#     <template id="gallerycarousel">
#         <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
#     </template>
#
#     <script src="//www.craigslist.org/js/general-concat.min.js?v=1ddd4a89b27ead11a5b226e8710fa94a" type="text/javascript" ></script>
#
#     <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
# <script type="text/template" id="clustertemplate">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script type="text/template" id="postingtemplate">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script type="text/template" id="popuptemplate">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=5ec3f46604456fbfe24ef4e789377c72" type="text/javascript" ></script>
#
#     <script src="//www.craigslist.org/js/search-concat.min.js?v=ea23af13894a92fd6ad04e324e272d41" type="text/javascript" ></script>
#
#     <script src="//www.craigslist.org/js/postings-concat.min.js?v=41bf2939565cec747e6f22d296638ee3" type="text/javascript" ></script>
#
# </body>
# </html>

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
tags = soup.find_all('a')

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/login?rt=L&rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fboston%252Ecraigslist%252Eorg%252Fsearch%252Fsof
# /search/sof
# /search/sof
# /search/sof?sort=date&
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html
# https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html
# https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6895717080.html
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6895717080.html
# #
# https://boston.craigslist.org/nwb/sof/d/andover-it-audit-manager/6895466532.html
# https://boston.craigslist.org/nwb/sof/d/andover-it-audit-manager/6895466532.html
# #
# https://boston.craigslist.org/gbs/sof/d/waltham-research-mobile-gps-developer/6895387139.html
# https://boston.craigslist.org/gbs/sof/d/waltham-research-mobile-gps-developer/6895387139.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-fullstack-engineer/6895134115.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-fullstack-engineer/6895134115.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-front-end-engineer/6895106101.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-front-end-engineer/6895106101.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6894411295.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6894411295.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6894410723.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6894410723.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6894397970.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6894397970.html
# #
# https://boston.craigslist.org/sob/sof/d/wrentham-programmer-developer/6894297679.html
# https://boston.craigslist.org/sob/sof/d/wrentham-programmer-developer/6894297679.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-full-time-junior-net-dev-2-days/6893887151.html
# https://boston.craigslist.org/gbs/sof/d/boston-full-time-junior-net-dev-2-days/6893887151.html
# #
# https://boston.craigslist.org/gbs/sof/d/lynn-co-founder-investor-wanted/6893293370.html
# https://boston.craigslist.org/gbs/sof/d/lynn-co-founder-investor-wanted/6893293370.html
# #
# https://boston.craigslist.org/gbs/sof/d/ba-qabusiness-analyst-quality-analyst/6893267113.html
# https://boston.craigslist.org/gbs/sof/d/ba-qabusiness-analyst-quality-analyst/6893267113.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-autonomous-vehicle-operator/6893248687.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-autonomous-vehicle-operator/6893248687.html
# #
# https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6891409509.html
# https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6891409509.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-project/6890564117.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-project/6890564117.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-vehicle-operator-toyota/6890499399.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-vehicle-operator-toyota/6890499399.html
# #
# https://boston.craigslist.org/gbs/sof/d/boxborough-multiple-technical-positions/6890363589.html
# https://boston.craigslist.org/gbs/sof/d/boxborough-multiple-technical-positions/6890363589.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6890235239.html
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6890235239.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6889890754.html
# https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6889890754.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6889890717.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6889890717.html
# #
# https://boston.craigslist.org/nos/sof/d/salem-entry-level-junior-developers/6889517543.html
# https://boston.craigslist.org/nos/sof/d/salem-entry-level-junior-developers/6889517543.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-salesforce-solutions-architect/6889444469.html
# https://boston.craigslist.org/gbs/sof/d/boston-salesforce-solutions-architect/6889444469.html
# #
# https://boston.craigslist.org/gbs/sof/d/lexington-senior-software-engineer/6889416821.html
# https://boston.craigslist.org/gbs/sof/d/lexington-senior-software-engineer/6889416821.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-short-term-software-development/6889209719.html
# https://boston.craigslist.org/gbs/sof/d/boston-short-term-software-development/6889209719.html
# #
# https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6889046082.html
# https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6889046082.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6889003225.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6889003225.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6888760638.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6888760638.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6888759759.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6888759759.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6888737728.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6888737728.html
# #
# https://boston.craigslist.org/bmw/sof/d/waltham-dev-ops-release-engineer/6887906682.html
# https://boston.craigslist.org/bmw/sof/d/waltham-dev-ops-release-engineer/6887906682.html
# #
# https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-training-placement/6887794411.html
# https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-training-placement/6887794411.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html
# https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html
# #
# https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html
# https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html
# https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html
# #
# https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html
# https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html
# https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html
# https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-react-engineer/6885873334.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-react-engineer/6885873334.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-ruby-on-rails-developer/6885873286.html
# https://boston.craigslist.org/gbs/sof/d/boston-ruby-on-rails-developer/6885873286.html
# #
# https://boston.craigslist.org/bmw/sof/d/waltham-we-need-your-data-engineering/6885374448.html
# https://boston.craigslist.org/bmw/sof/d/waltham-we-need-your-data-engineering/6885374448.html
# #
# https://boston.craigslist.org/gbs/sof/d/woburn-product-manager/6885275761.html
# https://boston.craigslist.org/gbs/sof/d/woburn-product-manager/6885275761.html
# #
# https://boston.craigslist.org/nos/sof/d/burlington-solutions-architect-customer/6884377885.html
# https://boston.craigslist.org/nos/sof/d/burlington-solutions-architect-customer/6884377885.html
# #
# https://boston.craigslist.org/gbs/sof/d/chestnut-hill-electronic-operations/6884343053.html
# https://boston.craigslist.org/gbs/sof/d/chestnut-hill-electronic-operations/6884343053.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-senior-business-systems-analyst/6883753487.html
# https://boston.craigslist.org/gbs/sof/d/boston-senior-business-systems-analyst/6883753487.html
# #
# https://boston.craigslist.org/nos/sof/d/peabody-it-systems-intern/6883655896.html
# https://boston.craigslist.org/nos/sof/d/peabody-it-systems-intern/6883655896.html
# #
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6883571127.html
# https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6883571127.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6882961036.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6882961036.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6882960389.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6882960389.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6882937735.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6882937735.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-apprentice-entrepreneur/6880819840.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-apprentice-entrepreneur/6880819840.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-junior-ux-and-visual-designer/6879669365.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-junior-ux-and-visual-designer/6879669365.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-dev-ops/6879668728.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-dev-ops/6879668728.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-lead-full-stack-developer-travel/6879309657.html
# https://boston.craigslist.org/gbs/sof/d/boston-lead-full-stack-developer-travel/6879309657.html
# #
# https://boston.craigslist.org/nwb/sof/d/harvard-devops-engineer/6879283391.html
# https://boston.craigslist.org/nwb/sof/d/harvard-devops-engineer/6879283391.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6879265559.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6879265559.html
# #
# https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6879089239.html
# https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6879089239.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-it-specialist-data-management/6879016616.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-it-specialist-data-management/6879016616.html
# #
# https://boston.craigslist.org/gbs/sof/d/jupiter-data-analyst-live-in-paradise/6878924751.html
# https://boston.craigslist.org/gbs/sof/d/jupiter-data-analyst-live-in-paradise/6878924751.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6878384051.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6878384051.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6878383344.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6878383344.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6878372498.html
# https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6878372498.html
# #
# https://boston.craigslist.org/sob/sof/d/east-walpole-junior-software-developer/6878194580.html
# https://boston.craigslist.org/sob/sof/d/east-walpole-junior-software-developer/6878194580.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-lead-development-director-at/6877962159.html
# https://boston.craigslist.org/gbs/sof/d/boston-lead-development-director-at/6877962159.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-qa-technician/6877759602.html
# https://boston.craigslist.org/gbs/sof/d/boston-qa-technician/6877759602.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-technology-and-data-coordinator/6877668445.html
# https://boston.craigslist.org/gbs/sof/d/boston-technology-and-data-coordinator/6877668445.html
# #
# https://boston.craigslist.org/gbs/sof/d/framingham-clinical-content-developer/6875769730.html
# https://boston.craigslist.org/gbs/sof/d/framingham-clinical-content-developer/6875769730.html
# #
# https://boston.craigslist.org/bmw/sof/d/natick-software-engineer-test-automation/6874633868.html
# https://boston.craigslist.org/bmw/sof/d/natick-software-engineer-test-automation/6874633868.html
# #
# https://boston.craigslist.org/gbs/sof/d/newtonville-vista-implementation/6874340537.html
# https://boston.craigslist.org/gbs/sof/d/newtonville-vista-implementation/6874340537.html
# #
# https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html
# https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html
# #
# https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html
# https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html
# #
# https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html
# https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html
# #
# https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html
# https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html
# #
# https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html
# https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html
# #
# #page-top
# #page-top
# /search/sof
# /search/sof
#
# https://boston.craigslist.org/search/sof?format=rss
# https://www.craigslist.org/about/rss
# https://www.craigslist.org/about/help/
# https://www.craigslist.org/about/scams
# https://www.craigslist.org/about/privacy.policy
# https://forums.craigslist.org/?forumID=8
# https://www.craigslist.org/about/craigslist_is_hiring
# //www.craigslist.org/about/terms.of.use.en-us
# https://www.craigslist.org/about/

# %% [markdown]
# ## Extracting Job titles & adresses.

# %%
titles = soup.find_all("a",{"class":"result-title"})

# %%
for title in titles:
    print(title.text)
# Out:
# Seeking iOS/Android Developer
# Senior Enterprise Analyst
# Cloud Engineer
# Quality Assurance (QA) Engineer
# Information Security Analyst
# IT AUDIT Manager
# Research / Mobile / GPS Developer For Transportation / Travel Startup
# Senior Fullstack Engineer
# Senior Front End Engineer
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Programmer/Developer
# Full time Junior C# .Net Dev - 2 days onsite, 3 days a week from home
# Co Founder / Investor Wanted
# BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
# Autonomous Vehicle Operator | Toyota Research Institute
# Minecraft, Roblox, & Coding Camp Program Lead
# Software Engineering Project Contract Hire (Remote Work)
# Vehicle Operator | Toyota Research Institute
# Multiple Technical Positions
# Information Security Analyst
# Systems Engineer
# Data Governance Manager
# Entry Level/Junior Developers
# Salesforce Solutions Architect - SFDC
# Senior Software Engineer
# short term software development
# Software Development Engineer I
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Dev Ops/Release Engineer
# In Class QA Training & Placement in Boston Area
# Systems Engineer
# Software Engineer - Python
# Minecraft, Roblox, & Coding Camp Program Lead
# Data Governance Manager
# Mobile Engineer
# Senior Software Big Data/Platform Engineer
# Senior .NET Developer
# ►►► Boston Job Fair!! Interviews on Tue, May 14 @ 11am
# Project Manager (Software Implementations)
# Implementation Engineer
# Senior React Engineer
# Ruby on Rails Developer
# We need your Data Engineering expertise!  Unlimited Vacation
# Product Manager
# Solutions Architect - Customer Engagement Offering
# Electronic Operations Specialist
# Senior Business Systems Analyst
# IT Systems Intern
# Information Security Analyst
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Apprentice Entrepreneur
# Junior UX and Visual Designer
# Software Engineer- Dev Ops
# Lead Full Stack Developer - Travel App
# DevOps Engineer
# Growth Stage Edtech Startup Hiring Full Stack Engineers
# Software Development Engineer I
# IT Specialist (Data Management )
# Data Analyst - Live in PARADISE (Relo available)
# Data Science Fellowship
# Product Management Fellow
# Software Engineering Fellow
# Junior Software Developer
# Lead Development Director at Hanareta (Tokyo Travel Startup)
# QA Technician
# Technology and Data Coordinator
# Clinical Content Developer
# Software Engineer - Test Automation
# Vista Implementation Specialist
# Summer DevOps Internship
# Data Manager
# Medical Equipment Inspection, Troubleshooting and Basic Repair
# Database Architect
# Business Analyst - UCONN

# %%
adresses = soup.find_all("span",{"class":"result-hood"})

# %%
for adress in adresses:
    print(adress.text)
# Out:
#  (Boston)
#  (Boston)
#  (Boston)
#  (Medford)
#  (Andover)
#  (Wrentham)
#  (Newbury St Boston)
#  (Boston Metro Area)
#  (Boston, MA)
#  (cambridge)
#  (Manchester-By-The-Sea)
#  (cambridge)
#  (Medford)
#  (Boston)
#  (Boston)
#  (Salem, MA)
#  (Lexington)
#  (boston)
#  (Waltham, MA)
#  (Cambridge MA)
#  (Walham)
#  (Malden)
#  (Boston)
#  (Boston)
#  (Manchester-By-The-Sea)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Brookline)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Boston)
#  (Burlington, MA)
#  (Medford)
#  (Boston)
#  (Peabody)
#  (Medford)
#  (Cambridge, MA)
#  (Cambridge)
#  (Cambridge, MA)
#  (BOXBOROUGH)
#  (Cambridge MA)
#  (Waltham, MA)
#  (Cambridge, MA)
#  (Jupiter)
#  (Norwood)
#  (Boston)
#  (Boston)
#  (Newton Massachusetts)
#  (Natick MA area)
#  (Newton)

# %%
## Extracting Job titles & adresses togather

# %%
jobs = soup.find_all('p',{'class':'result-info'})

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time',{'class':'result-date'}).text
    link = job.find('a',{'class':'result-title'}).get('href')
    print('Job Title:', title, '\nLocation', location, '\nDate:', date, '\nLink:', link, '\n---')
# Out:
# Job Title: Seeking iOS/Android Developer
# Location N/A
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html
# ---
# Job Title: Senior Enterprise Analyst
# Location Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html
# ---
# Job Title: Cloud Engineer
# Location Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html
# ---
# Job Title: Quality Assurance (QA) Engineer
# Location Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html
# ---
# Job Title: Information Security Analyst
# Location Medford
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6895717080.html
# ---
# Job Title: IT AUDIT Manager
# Location Andover
# Date: May 23
# Link: https://boston.craigslist.org/nwb/sof/d/andover-it-audit-manager/6895466532.html
# ---
# Job Title: Research / Mobile / GPS Developer For Transportation / Travel Startup
# Location N/A
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/waltham-research-mobile-gps-developer/6895387139.html
# ---
# Job Title: Senior Fullstack Engineer
# Location N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-fullstack-engineer/6895134115.html
# ---
# Job Title: Senior Front End Engineer
# Location N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-front-end-engineer/6895106101.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6894411295.html
# ---
# Job Title: Product Management Fellow
# Location N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6894410723.html
# ---
# Job Title: Software Engineering Fellow
# Location N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6894397970.html
# ---
# Job Title: Programmer/Developer
# Location Wrentham
# Date: May 21
# Link: https://boston.craigslist.org/sob/sof/d/wrentham-programmer-developer/6894297679.html
# ---
# Job Title: Full time Junior C# .Net Dev - 2 days onsite, 3 days a week from home
# Location Newbury St Boston
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-time-junior-net-dev-2-days/6893887151.html
# ---
# Job Title: Co Founder / Investor Wanted
# Location Boston Metro Area
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/lynn-co-founder-investor-wanted/6893293370.html
# ---
# Job Title: BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
# Location Boston, MA
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/ba-qabusiness-analyst-quality-analyst/6893267113.html
# ---
# Job Title: Autonomous Vehicle Operator | Toyota Research Institute
# Location cambridge
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-autonomous-vehicle-operator/6893248687.html
# ---
# Job Title: Minecraft, Roblox, & Coding Camp Program Lead
# Location Manchester-By-The-Sea
# Date: May 17
# Link: https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6891409509.html
# ---
# Job Title: Software Engineering Project Contract Hire (Remote Work)
# Location N/A
# Date: May 16
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-project/6890564117.html
# ---
# Job Title: Vehicle Operator | Toyota Research Institute
# Location cambridge
# Date: May 16
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-vehicle-operator-toyota/6890499399.html
# ---
# Job Title: Multiple Technical Positions
# Location N/A
# Date: May 16
# Link: https://boston.craigslist.org/gbs/sof/d/boxborough-multiple-technical-positions/6890363589.html
# ---
# Job Title: Information Security Analyst
# Location Medford
# Date: May 16
# Link: https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6890235239.html
# ---
# Job Title: Systems Engineer
# Location Boston
# Date: May 15
# Link: https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6889890754.html
# ---
# Job Title: Data Governance Manager
# Location Boston
# Date: May 15
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6889890717.html
# ---
# Job Title: Entry Level/Junior Developers
# Location Salem, MA
# Date: May 15
# Link: https://boston.craigslist.org/nos/sof/d/salem-entry-level-junior-developers/6889517543.html
# ---
# Job Title: Salesforce Solutions Architect - SFDC
# Location N/A
# Date: May 15
# Link: https://boston.craigslist.org/gbs/sof/d/boston-salesforce-solutions-architect/6889444469.html
# ---
# Job Title: Senior Software Engineer
# Location Lexington
# Date: May 15
# Link: https://boston.craigslist.org/gbs/sof/d/lexington-senior-software-engineer/6889416821.html
# ---
# Job Title: short term software development
# Location boston
# Date: May 15
# Link: https://boston.craigslist.org/gbs/sof/d/boston-short-term-software-development/6889209719.html
# ---
# Job Title: Software Development Engineer I
# Location Waltham, MA
# Date: May 14
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6889046082.html
# ---
# Job Title: Growth Stage Edtech Startup Hiring Full Stack Engineers
# Location Cambridge MA
# Date: May 14
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6889003225.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: May 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6888760638.html
# ---
# Job Title: Product Management Fellow
# Location N/A
# Date: May 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6888759759.html
# ---
# Job Title: Software Engineering Fellow
# Location N/A
# Date: May 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6888737728.html
# ---
# Job Title: Dev Ops/Release Engineer
# Location Walham
# Date: May 13
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-dev-ops-release-engineer/6887906682.html
# ---
# Job Title: In Class QA Training & Placement in Boston Area
# Location Malden
# Date: May 13
# Link: https://boston.craigslist.org/gbs/sof/d/malden-in-class-qa-training-placement/6887794411.html
# ---
# Job Title: Systems Engineer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-systems-engineer/6886187941.html
# ---
# Job Title: Software Engineer - Python
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineer-python/6886093658.html
# ---
# Job Title: Minecraft, Roblox, & Coding Camp Program Lead
# Location Manchester-By-The-Sea
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/manchester-minecraft-roblox-coding-camp/6886055103.html
# ---
# Job Title: Data Governance Manager
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-governance-manager/6885987835.html
# ---
# Job Title: Mobile Engineer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-mobile-engineer/6885987794.html
# ---
# Job Title: Senior Software Big Data/Platform Engineer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-big-data/6885987745.html
# ---
# Job Title: Senior .NET Developer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-net-developer/6885987698.html
# ---
# Job Title: ►►► Boston Job Fair!! Interviews on Tue, May 14 @ 11am
# Location Brookline
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/brookline-boston-job-fair-interviews-on/6885914203.html
# ---
# Job Title: Project Manager (Software Implementations)
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-project-manager-software/6885873440.html
# ---
# Job Title: Implementation Engineer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-implementation-engineer/6885873392.html
# ---
# Job Title: Senior React Engineer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-react-engineer/6885873334.html
# ---
# Job Title: Ruby on Rails Developer
# Location Boston
# Date: May 10
# Link: https://boston.craigslist.org/gbs/sof/d/boston-ruby-on-rails-developer/6885873286.html
# ---
# Job Title: We need your Data Engineering expertise!  Unlimited Vacation
# Location Boston
# Date: May  9
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-we-need-your-data-engineering/6885374448.html
# ---
# Job Title: Product Manager
# Location N/A
# Date: May  9
# Link: https://boston.craigslist.org/gbs/sof/d/woburn-product-manager/6885275761.html
# ---
# Job Title: Solutions Architect - Customer Engagement Offering
# Location Burlington, MA
# Date: May  8
# Link: https://boston.craigslist.org/nos/sof/d/burlington-solutions-architect-customer/6884377885.html
# ---
# Job Title: Electronic Operations Specialist
# Location Medford
# Date: May  8
# Link: https://boston.craigslist.org/gbs/sof/d/chestnut-hill-electronic-operations/6884343053.html
# ---
# Job Title: Senior Business Systems Analyst
# Location Boston
# Date: May  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-business-systems-analyst/6883753487.html
# ---
# Job Title: IT Systems Intern
# Location Peabody
# Date: May  7
# Link: https://boston.craigslist.org/nos/sof/d/peabody-it-systems-intern/6883655896.html
# ---
# Job Title: Information Security Analyst
# Location Medford
# Date: May  7
# Link: https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6883571127.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: May  6
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6882961036.html
# ---
# Job Title: Product Management Fellow
# Location N/A
# Date: May  6
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6882960389.html
# ---
# Job Title: Software Engineering Fellow
# Location N/A
# Date: May  6
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6882937735.html
# ---
# Job Title: Apprentice Entrepreneur
# Location Cambridge, MA
# Date: May  3
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-apprentice-entrepreneur/6880819840.html
# ---
# Job Title: Junior UX and Visual Designer
# Location Cambridge
# Date: May  2
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-junior-ux-and-visual-designer/6879669365.html
# ---
# Job Title: Software Engineer- Dev Ops
# Location Cambridge, MA
# Date: May  2
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-dev-ops/6879668728.html
# ---
# Job Title: Lead Full Stack Developer - Travel App
# Location N/A
# Date: May  1
# Link: https://boston.craigslist.org/gbs/sof/d/boston-lead-full-stack-developer-travel/6879309657.html
# ---
# Job Title: DevOps Engineer
# Location BOXBOROUGH
# Date: May  1
# Link: https://boston.craigslist.org/nwb/sof/d/harvard-devops-engineer/6879283391.html
# ---
# Job Title: Growth Stage Edtech Startup Hiring Full Stack Engineers
# Location Cambridge MA
# Date: May  1
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-growth-stage-edtech-startup/6879265559.html
# ---
# Job Title: Software Development Engineer I
# Location Waltham, MA
# Date: May  1
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/6879089239.html
# ---
# Job Title: IT Specialist (Data Management )
# Location Cambridge, MA
# Date: May  1
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-it-specialist-data-management/6879016616.html
# ---
# Job Title: Data Analyst - Live in PARADISE (Relo available)
# Location Jupiter
# Date: May  1
# Link: https://boston.craigslist.org/gbs/sof/d/jupiter-data-analyst-live-in-paradise/6878924751.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: Apr 30
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6878384051.html
# ---
# Job Title: Product Management Fellow
# Location N/A
# Date: Apr 30
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6878383344.html
# ---
# Job Title: Software Engineering Fellow
# Location N/A
# Date: Apr 30
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6878372498.html
# ---
# Job Title: Junior Software Developer
# Location Norwood
# Date: Apr 30
# Link: https://boston.craigslist.org/sob/sof/d/east-walpole-junior-software-developer/6878194580.html
# ---
# Job Title: Lead Development Director at Hanareta (Tokyo Travel Startup)
# Location N/A
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-lead-development-director-at/6877962159.html
# ---
# Job Title: QA Technician
# Location Boston
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-qa-technician/6877759602.html
# ---
# Job Title: Technology and Data Coordinator
# Location Boston
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-technology-and-data-coordinator/6877668445.html
# ---
# Job Title: Clinical Content Developer
# Location Newton Massachusetts
# Date: Apr 26
# Link: https://boston.craigslist.org/gbs/sof/d/framingham-clinical-content-developer/6875769730.html
# ---
# Job Title: Software Engineer - Test Automation
# Location Natick MA area
# Date: Apr 25
# Link: https://boston.craigslist.org/bmw/sof/d/natick-software-engineer-test-automation/6874633868.html
# ---
# Job Title: Vista Implementation Specialist
# Location Newton
# Date: Apr 25
# Link: https://boston.craigslist.org/gbs/sof/d/newtonville-vista-implementation/6874340537.html
# ---
# Job Title: Summer DevOps Internship
# Location N/A
# Date: May  3
# Link: https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html
# ---
# Job Title: Data Manager
# Location N/A
# Date: May 15
# Link: https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html
# ---
# Job Title: Medical Equipment Inspection, Troubleshooting and Basic Repair
# Location N/A
# Date: May  4
# Link: https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html
# ---
# Job Title: Database Architect
# Location N/A
# Date: May  5
# Link: https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html
# ---
# Job Title: Business Analyst - UCONN
# Location N/A
# Date: Apr 25
# Link: https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html
# ---

# %%
# Let's add some more attributes of jobs !!

for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time', {'class': 'result-date'}).text
    link = job.find('a', {'class': 'result-title'}).get('href')
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section',{'id':'postingbody'}).text
    job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
    job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
    
    print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
# Out:
# Job Title: Seeking iOS/Android Developer
# Location: N/A
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html
#
# compensation: $15-$35/hr based on experience/proficiency
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# New Movie Review App Seeking Head Developer
#
# We’re looking for a developer proficient in iOS and Android	(Xcode/java) to work hourly on new features; as well as over see ongoing code for both platforms for smaller/simpler features.
# Our app is simple and straightforward. We have a wonderful and talented developer for our backend/PHP. We’re great people to work with and have big plans for the app, so ideally we're looking for someone long term.
#
# (Open to all applicants but especially interested in POC/Women and individuals in the US time zones)
#
# Looking forward to hearing from you. Please email any resume/samples of your work.
#
# https://itunes.apple.com/us/app/qurator-app/id1450485928?mt=8
# ---
# Job Title: Senior Enterprise Analyst
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/d3e39f45-97b0-4145-9ef8-e6bcb1c2b3a1?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# About The Team
#
# The Information Systems (IS) team’s mission is to apply information and technology in collaboration with other business units and external stakeholders to improve operating efficiencies and promote innovation across the company. The team plays a key role in leading collaboration with others while creating digital strategies, embracing organizational changes, adopting agile practices, and experimenting with emerging technologies. They do all this while being compliant and secure by enforcing internal policies which are aligned to organizational strategy and vision.
#
# About The Role
#
# The Senior Enterprise Analyst will be a member of the Information Systems team and will be responsible to execute and support IS projects in collaboration with the Business Insights, Information Systems, Marketing, Customer Success, Engineering, and Product teams with direction from the Director of Information Systems. We are looking for a creative problem solver who is passionate about leveraging technology in support of greater operational efficiency for the entire organization. The ideal candidate is analytical, empathetic, customer centric, and thrives in a fast-paced startup environment. This position reports to Director of Information Systems and is located in Boston, MA.
#
# What You'll Do
#
# - Work closely with Business Insights team in providing services related to Data Modeling/Analytics, Business Intelligence, Data Warehousing and Reporting
# - Develop workflow diagrams and functional requirements to communicate with stakeholders
# - Implement and proactively manage the ETL design and development based on MS SQL Server, SSIS, Azure Data Service (Data Factory, Data Lake Storage, Data Warehouse etc.)
# - Communicate effectively to various stakeholders with status updates
# - Identify and cleanse data from external data sources (SalesForce, Marketing Cloud, Google Analytics, Google Adwords, Zendesk, Paypal, Quickbooks etc.)
# - Pursue training and professional development opportunities, strive to continuously build knowledge and skills, stay on top of new trends in Data Modeling, Analytics, ETL and related technologies and share expertise to the team
# - Work closely with marketing team to support/enhance MarTech stack including but not limited to all the integration
# - Prepare and update documentation related to work done
#
# What You'll Bring
#
# - Experience developing data warehousing solutions using SSIS, SQL Server, Azure Data Service
# - Strong ETL experience coupled with Strong SQL knowledge
# - Experience with creating and using SQL procedures, functions and queries
# - Experience with data cleansing, data analysis and profiling
# - Experience creating KPI dashboards and reports using PowerBI from data warehouse
# - Experience with MarTech stack such as Google Analytics, AdWords, Marketing Cloud etc. is a plus
# - Strong communication skills
# - Strong passion for data, analytics, modeling, and relevant technologies
# - Enthusiasm for continuous learning in the always changing information systems landscape
# - Experience working independently and within a team with diverse internal stakeholder groups
# - Ability to work in a fast-paced agile software development environment, handling multiple projects, requests and tasks effectively
#
# Preferred Qualifications/Experience
#
# - BS or equivalent in Computer Science, Information Systems, Data Science or equivalent technical degree
# - 5+ years’ experience in relational and data warehouse database design, optimization and performance; preferably with SSIS, SQL Server
# - Experience developing ETL specifications and mappings to support data integration from external datasources
# - Experience with Azure SQL products and services will be a plus
# - Strong knowledge of referential integrity, triggers, stored procedures and functions
# - Experience with reporting and data visualization application (PowerBI)
# - Understanding of project management and software development lifecycle
# - Experience in maintaining high level of customer satisfaction
# - Possess excellent problem-solving, analytical and time management skills
# - Self-starter, highly motivated, able to shift directions quickly when priorities change
# - Excellent verbal and written communication skills, with ability to present complex ideas in a clear, concise manner
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
#
# ---
# Job Title: Cloud Engineer
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/abcd96c3-3308-4725-9b72-e8856d8e81ac?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home, throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# About The Team
#
# The Information Systems (IS) team’s mission is to apply information and technology in collaboration with other business units and external stakeholders to improve operating efficiencies and promote innovation across the company. The team plays a key role in leading collaboration with others while creating digital strategies, embracing organizational changes, adopting agile practices, and experimenting with emerging technologies. They do all this while being compliant and secure by enforcing internal policies which are aligned to organizational strategy and vision.
#
# About The Role
#
# The Cloud Engineer will be a member of the Information Systems team and will be responsible to implement and support Continuous Delivery and Continuous Integration on all Software Development projects and initiatives within Framework. This role works in collaboration with the Engineering and Product Development teams. We are looking for a person with adequate domain knowledge and hands-on experience in developing and implementing software projects. This person will be responsible for maintaining and improving the CI/CD pipelines in an agile software development environment. This role reports to the Director of Information Systems and is based in Boston, MA
#
# What You'll Do
#
# -Assist the Engineering team to implement and enhance CI/CD
# -Work closely with the Information Systems and Engineering teams to manage and provide help/guidance with CI/CD
# - Proactively manage, maintain, and monitor all CI/CD pipelines
# - Assist and proactively manage the operation of IS backend systems including MS SQL Server, SSIS, Azure Data Service (Data Factory, Data Lake Storage, Data Warehouse etc.)
# - Communicate effectively to various stakeholders with status updates
# - Pursue training and professional development opportunities, strive to continuously build knowledge and skills, stay on top of new trends in CI/CD pipelines, software technologies related to cloud-based deployments and share expertise to the team
# - Prepare and update documentation related to work done
#
# What You'll Bring
#
# - Experience in Continuous Integration/Continuous Delivery techniques, test-driven development, and automated build and testing procedures
# - Passion to engage in continuous learning to ensure knowledge of latest DevOps Techniques, Technologies, and cloud (AWS, Azure) product updates • Passion for coding, problem solving, testing, and maintenance
# - Experience in developing customized code, scripts, modules, procedures using languages such as Python, Java, JavaScript, Bash, and other scripting and development languages
# - Experience working independently and within a team with diverse internal stakeholder groups
# - Ability to work in a fast-paced agile software development environment handling multiple projects, requests, and tasks effectively
#
# Preferred Qualifications/Experience
#
# - BS or equivalent in Computer Science, Engineering, Mathematics or equivalent technical degree •
# 3-5 years’ experience in full stack development using Java, Web Services, Database and microservice development
# - Strong background and experience building and maintaining CI/CD infrastructure automation (Amazon pipeline, Jenkins)
# - Amazon Web Services including EC2, ECS, S3, CloudWatch, Lambda
# - Experience using configuration management tools such as GitHub
# - Experience with Systems Monitoring/Alerting tools (PagerDuty, CloudWatch, DataDog, NewRelic)
# - Experience with container orchestration utilizing docker images (Node.js, Spring Boot applications)
# - Experience with github, maven, scripting (bash, python etc.), databases (postgreSQL, SQL Server)
# - AWS Certifications are definitely a plus for this position
# - Experience with Microsoft SQL Server, SSIS, Power BI and Azure Cloud Service technologies is a plus for this position
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
# ---
# Job Title: Quality Assurance (QA) Engineer
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/9d41b1cf-3b43-4842-9619-0b0740ef5264?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Team
#
# The Engineering team’s mission is to architect and develop innovative mobile and web applications by applying computer science, mathematics, engineering and other disciplines, and collaborating with other business units and external stakeholders. The team plays a vital role in leading collaboration across the company by putting together a tech stack to support platform strategy, which in turn supports various revenue models. They do all this while adopting agile practices and experimenting with emerging technologies for the organization to innovate, as well as remaining compliant and secure and enforcing internal policies which are aligned to organizational strategy and vision.
#
# About the Role
#
# The QA Engineer will develop and launch initiatives that expand our platform and position the company as a leading online resource for our next phase of growth. The person in this role will play a critical role on the Engineering team, creating and implementing QA strategies as well as developing solutions to identified quality problems.
#
# What You'll Do
#
# - Test new Framework platform and software products, and identify deficiencies
# - Develop solutions to identified product problems
# - Plan, create, and manage the overall Quality Planning strategy
# - Provide regular status updates to all assigned sprint tasks in daily stand-up meetings
# - Collaborate and work closely with the product team and scrum master to complete tasks assigned during the sprint planning
# - Identify quality assurance process bottleneck and suggest actions for improvement
# - Analyze, troubleshoot, and resolve production system issues and defects
# - Automate tests with CI/CD pipelines
# - Prepare and present reports with key metrics to Management
# - Develop escalation procedures and policies for different types of issues
# - Understand Framework’s business, customers, and products
#
# What You’ll Bring
#
# - 5 years of experience as a Quality Assurance Engineer
# - Experience working with a variety of different testing techniques such as Mobile App / UI / API Testing, Automated Testing, Test Driven Development Strategies and other
# - Experience with coding using JAVA, Groovy scripts, HTML5, XML
# - Experience with web security technology
# - Experience with software QA tools and processes
# - Understanding of Agile development methodology (Scrum)
# - Demonstrated critical thinking and problem-solving skills
# - Great interpersonal and communication skills; a team player
# - Excellent analytical, organizational, and decision-making skills
# - A sense of ownership and pride in your performance and its impact on the company’s success
# - Ability to thrive in an entrepreneurial and nimble environment; bonus, this excites you
# - Our vision inspires you!
#
# Specific Knowledge Areas
#
# Ready API (SoapUI) and other test automation tools, JSON, JavaScript/Java/Groovy, ReactJS, AWS, PostgreSQL, HTML5, CSS, CSS3, XML, User Interface (UI), Web Services (REST/SOAP), API
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home, throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
# ---
# Job Title: Information Security Analyst
# Location: Medford
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6895717080.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job Overview:
# ---
# Job Title: IT AUDIT Manager
# Location: Andover
# Date: May 23
# Link: https://boston.craigslist.org/nwb/sof/d/andover-it-audit-manager/6895466532.html
#
# compensation: $90-$110+benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We have a tremendous opportunity for a driven, self motivated IT/Controls professional who will complete compliance assessments and identify control deficiencies to ensure compliance with regulations, internal controls, policies and procedures; recommend improvements in internal control structure; identify control deficiencies; conduct independent assessments of third parties; conduct assessments for utility regulations, including SOX, GDPR, Data Privacy, Cybersecurity and other federal and state regulations.
#
# Qualifications and Skills
#
# CISA certification a plus
# CRISC certification, CISM a plus
# 1-3 Years of IS Audit Experience
# Understanding of assessing third party service providers and associated risks
# Understanding of SSAE 18 ISAE 3402, SOC 1, SOC 2 reports
#
#
# ---
# Job Title: Research / Mobile / GPS Developer For Transportation / Travel Startup
# Location: N/A
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/waltham-research-mobile-gps-developer/6895387139.html
#
# compensation: TBD
#
# employment type: contract
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Transportation/travel/tourism early startup at pre-funding stage seeks experienced software / systems developer  / programmer to help design specifications for various research projects leading to development of prototype/POC.  Proprietary research gathered over the past several years serves as basis for unique transportation/travel based service piloted in the Boston area and ultimately rolled out to other cities.
#
# Ideal candidate might have an existing job and could perform pro-bono research / design projects.  We are applying for federal seed funding under the SBIR program.  Upon funding candidate will join as CTO/lead and be paid for the development work required to build the POC/service.  Potential for equity.
#
# Transportation/travel/location related development experience a plus.
#
# Specifications/architecture to be defined include:
#
# 1.	Design innovative technologies, software, systems to be used for in vehicle presentation, labor/resource/demand usage/prediction, data storage/backup and other vehicle/trip related information (ie, iPhone/iPad/Android/GUI/app design, GPS, wireless communication, cloud sharing, cyber security, e-commerce, vehicle systems, BI, etc.)
#
# 2.	Design / customize automated GPS systems to for navigation use for drivers, automate/innovate use of technologies such as GPS (ie, Waze, Google Maps)
#
# 3.	Develop big data processing/predictive analytics/AI systems related to generating and forecasting auto usage from potential customers using technologies such as website or apps
#
# 4.	Design app based scheduling processes for travel / transportation related business
#
# 5.	Define feasibility of various proposed routes as well as logistics (ie, GPS route planning, time of day/day of month travel issues, anticipated traffic congestion, demand forecasting, health/safety factors, coordination with city closures – holidays, construction, accidents, etc.)
#
# 6.	Understand appropriate technologies and issues relating to web and mobile based content management systems, communication systems for data exchange/updates, and data security issues relating to updating customer tracking and in-car activities
#
# 7.	Understand how to scale various service offerings as business scales (hiring needs, website/app traffic increases, incorporation of new technologies or features, partnering with larger travel companies, health/safety issues, etc.)
#
# 8.	Understand how to apply technology developments / lessons learned from a pilot city can apply to new cities
#
# 9.	Design new systems for underserved communities including special apps, podcasting, or
# special technology services (ie, blind, deaf, disabled, elderly)
#
# 10.	Define new technology based in car advertising systems that can be implemented by sponsor companies (ie, dynamic in car display and/or on website ad systems)
#
# Please forward your CV, examples of prior work and a thoughtful cover letter with your interest. Thank you.
# ---
# Job Title: Senior Fullstack Engineer
# Location: N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-fullstack-engineer/6895134115.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our client in Boston, MA is looking for an experienced Senior Fullstack Engineer to join their team. In this role, you will design and develop products and services used by millions of people every day. You will also act as a leader within the team and be involved in large, customer facing projects, architecture, product roadmaps and mentoring of other team members.
#
# Requirements:
# - 5+ years of experience in software development
# - Customer focused mentality
# - Proven proficiency with Javascript
# - Experience working on large scale projects
#
# Relocation and visa sponsorship provided if necessary.
#
# Please upload a copy of your resume detailing relevant work experience for consideration!
# ---
# Job Title: Senior Front End Engineer
# Location: N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-front-end-engineer/6895106101.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our client in Boston, the largest home goods website, is looking to add a Senior Front End Software Engineer to their rapidly growing team. Their engineering goal is to make sure each customer has an enjoyable shopping experience.  As a Senior Software Engineer you will be help lead and drive projects, write code that is seen by millions of customers daily, and help make decisions that influence how customers shop online.
#
# Qualifications:
# - 5+ years of Javascript development experience
# - Javascript experience
# - HTML/CSS experience a plus
# - React experience a plus
# - Bachelor of Science in Computer Science or related STEM Field (Applied Math, Computer Engineering, etc.)
#
# This is a full-time, direct-hire position with competitive compensation packages. Relocation assistance and visa sponsorship is provided if needed.
#
# Please provide an updated resume detailing your relevant work and educational experience.
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6894411295.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSData&utm_campaign=CLBOSData&utm_medium=web
# ---
# Job Title: Product Management Fellow
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6894410723.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSProduct&utm_campaign=CLBOSProduct&utm_medium=web
# ---
# Job Title: Software Engineering Fellow
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6894397970.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSSWE&utm_campaign=CLBOSSWE&utm_medium=web
# ---
# Job Title: Programmer/Developer
# Location: Wrentham
# Date: May 21
# Link: https://boston.craigslist.org/sob/sof/d/wrentham-programmer-developer/6894297679.html
#
# compensation: Up to US$0.00 per year
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Volt has partnered with an electrical manufacturing company to offer this opportunity to someone with a strong background as a Programmer. If interested, please take the time to apply!ProgrammerHours: 8:00 am - 5:00 pmLocation: Foxboro, MADescription:A CAD/CAM Programmer creates drawings and CNC programs using the provided CAD/CAM software. This individual should be proficient with Microsoft Office software (Outlook, Excel, and Word) as well as be able to create new, maintain, and update files from that software. Being able to determine the manufacturing process of a new product from the fixture/holding stage to the finish product is essential for this position.Skills:OutlookExcelWordCreate Drawings & CNC ProgramsExtensive knowledge or C#C, C++, python, bash, batch, VB, .NET, PLC ladder logic, HTML, Javascript, CSS, and build automation (two to three or more of these are needed, not all – but you must have the willingness and aptitude to learn needed technologies and languages quickly)Professional Experience/ Education:Previous Programming experienceAssociates degree in related field minimumWe have a long-standing tradition of developing lasting and mutually beneficial relationships with our employees.  Contact a Volt representative by applying to this posting online for immediate consideration. Submit your resume today!Volt is an Equal Opportunity Employer.
#
# ---
# Job Title: Full time Junior C# .Net Dev - 2 days onsite, 3 days a week from home
# Location: Newbury St Boston
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-time-junior-net-dev-2-days/6893887151.html
#
# compensation: $65,000-$80,000 with healthcare benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# https://thirdeyehealth.net/
#
# Third Eye Health is a national healthcare company providing high quality remote and bedside medical care to acute, post-acute, and senior care organizations.
#
# We are looking for an individual with at least 2 years experience of experience coding C# / SQL for our .NET Core applications.
#
# Experience with swift for iOS mobile app development will put you at the top of the list as you might also be working on our mobile applications that allows physicians to securely send text messages, pictures and stream live video, but to begin with will be writing C# code for our web consult documentation application.
#
# Bachelor Degree in Computer Science required.
#
# You will be working directly with our CTO & one of our developers out of office on Newbury St in Boston two days a week and remotely the other three days.
#
# Please send along a C# code snippet that you've written that is at least 100 lines long.
#
# Job Type: Full-time
#
# Experience:
#
# SQL: 2 years (Required)
# C#: 2 years (Required)
# iOS: 1 year (Preferred)
#
# Education:
#
# Bachelor's (Required)
# ---
# Job Title: Co Founder / Investor Wanted
# Location: Boston Metro Area
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/lynn-co-founder-investor-wanted/6893293370.html
#
# compensation: Equity - Stock Compensation Package
#
# employment type: contract
#
# internship
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Wanted Co-Founder /Investor Wanted to help with a Multimedia Digital Content Entertainment Application product for the 35 million Devoted Weekly Lottery Players in the United States, and then into other countries around the world in the $220 billion dollar industry. I’m the Founder and Creator of LottoGraphs Animated Lottery Videos.
#
# It’s a blend of Computer Animation and Lottery Historical Data. We call it ”LottoMation”.
#
# See it in action and in Real Time At =  https:/www.LottoGraphs.tv
# Create a Free Account then ping me when you complete for a free account upgrade !
#
# We ready to go to Market with all the Massachusetts Lottery Games Completed, which has the highest per capita spend on the lottery in the USA. We need a Marketing Professional who can deliver it to the consumer both B2C and B2B.
# We need a Developer who can complete some easy programming task for other state lottery code modules.
# Click the Executive Summary Button with Due Diligence URL Reference Links for your convenience for more info on the product and industry. https://lottographs.tv/investors-relations/
#
# Pitch to Investors Video  https://www.youtube.com/watch?v=LfQxWSCFuzk
#
# EQUITY - DEVELOPER NEEDED, MUST BE WILLING TO ACCEPT STOCK FOR PAYMENT
# This shows us that you are truly interested in working on this unique project with us. !!
# Must Have Experience with Javascript, HTML5, CSS3, PHP, MySQL
# Mobile App Development, with Android, Apple iOS, Windows Mobile would be a plus
# Ability to help us build a modern technical stack and make 3rd party integrations.
# Able to test and troubleshoot bugs across browsers and devices
# Work can be done remotely but must be available to meet in, Lynn or Boston weekly.
# We’ll ask that you sign a non-disclosure and confidentiality agreement for this project.
#
# If you would like to learn more about the Unique Opportunity, Please Contact me via email first. !
#
# Have a Productive Day Ahead
#
# William B. Lott Jr.
# Founder & Creator of
# LottoGraphs Animated Lottery Videos
# 781-558-7277
# Skype ID = william.lott8
# wlott2004@yahoo.com
# www.LottoGraphs.tv
# Google Us = LottoGraphs
#
#
# ---
# Job Title: BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
# Location: Boston, MA
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/ba-qabusiness-analyst-quality-analyst/6893267113.html
#
# compensation: DOE
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
#
#
# For more information please call 732 250 3906
#
# Demo Introduction Video: www.youtube.com/watch?v=SHj5bH6VTu8
#
#
# We offer a Combo BA/QA Course where the students can learn the concepts of BA/QA in the same Program with out any additional effort. This also gives the flexibility for the students to choose the best Career option...BA or QA at the end of the course.
#
# 100% JOB PLACEMENT ASSISTANCE RECORD. ALSO SPECIALIZE IN JOBS PLACEMENTS IN NJ,NY as we work mostly with LOCAL CLIENTS in EAST COAST.
#
# We offer detailed ,comprehensive and Job Oriented training in Business Analyst/Quality Analysis with Placement Assistance.
# Flexible timings on Weekdays/Weekends
# Professional guidance for resume preparation and interviews
# Counseling/One-on-one discussion with Trainer to clarify your doubts.
# Flexible timings for the training.
# Aggressive marketing by experienced placement team
# H1b and Green cards sponsorship for deserving candidates
# Training for Certifications and Reimbursement for Certifications on a need basis.
# Professional Training and training material.
# We are currently looking for Citizens/GC holders/OPT/CPT holders/ H1B
# We provide excellent benefits like
#
# Competitive Salary or hourly rates.
# Health Insurance.
# Corporate training opportunities
# Job Placement
# Resume Preparation
# Discussion on Interview Questions
# Job Placement Support
# On Job Support
#
#
# For more information please call 732 250 3906
# QA Testing Course Content
# Introduction to Software Testing
# • What is Software Testing?
#
# Software Development Life cycle
# • Requirements
# • Analysis
# • Design
# • Coding
# • Testing
# • Acceptance
#
# SDLC Models
# • Agile
# • Waterfall model
# • Spiral model
# • V-Model
#
# Testing-Methods
# • White Box Testing
# • Black Box testing
# • Gray Box testing
#
# Types of Testing (Black Box Testing)
# • Build Verification Testing
# • Functional Testing
# • Integration Testing
# • Regression Testing
# • System Testing
# • Acceptance Testing
# • Smoke and Sanity Testing
# • Ad-hoc Testing
# • Exploratory Testing
# • Compatibility Testing
# • Disaster Recovery Resting
# • Load, Volume, Stress and Performance Testing
#
# Testing Life Cycle / Quality Assurance Life Cycle / Software Testing Life Cycle
# • Requirements
# • System study
# • Test plan
# • Test Cases
# • Traceability Matrix
# • Test case execution
# • Defect tracking
# • Test Summary Report
# • User Acceptance Testing
#
# Test Plan
# • Objective
# • Scope
# • Approach
# • Methodologies
# • Deliverables
# • Test environment
# • Schedule and Resources
# • Effort and estimation
# • Entry and Exit criteria
# • Templates
# • Risk
# • Assumption
# • Contingency Plan
# • References
#
# Test Case
# • Test Case Design
# • How to write test cases
# • When to execute test cases
#
# Checklists
# • How to create checklists
# • When to use checklists
#
# Defect tracking
# • Defect life cycle
# • Severity, priority
# • Defect tracking Tool -- Quality Center, Bugzilla and Rational Clear Quest
# • Defect report
# • Defect Tracking Sheet
# • OK for recruiters to contact this job poster.
# • do NOT contact us with unsolicited services or offers
#
#
# •	OK for recruiters to contact this job poster.
# •	do NOT contact us with unsolicited services or offers
#
#
# ---
# Job Title: Autonomous Vehicle Operator | Toyota Research Institute
# Location: cambridge
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-autonomous-vehicle-operator/6893248687.html
#
# compensation: Competitive
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/122f7259/apply
#
#
# HireArt is looking to hire a Vehicle Operator to work at Toyota Research Institute’s (TRI) Cambridge location on a contract basis. We're seeking motivated individuals with a passion for technology to join the Driving Operations Team. You'll be responsible for TRI’s autonomous vehicle platforms on various public and private roads obtaining data and fixing technical issues. As a specialist within Driving Operations, you're a valuable contributor, providing necessary feedback to our engineering team aimed at improving groundbreaking automated driving technology.Toyota Research Institute (TRI) is working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join TRI’s mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. TRI is dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. TRI strives  to build a company that helps people thrive, achieve work life balance, and bring their best selves to work. You will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you.Job Responsibilities:
# Maintain Toyota's high standard of safety, inside and outside of the vehicles.
# Consistently demonstrate situational awareness, an understanding of the technology in your care, and a willingness to constantly adjust to changes in the environment.
# Conduct a variety of critical data collection for engineering teams using complex proprietary software and hardware, and communicate through multiple channels.
# Be an ambassador for the technology by communicating expertly and courteously at all times with management, engineers, and members of the public.
# Travel outside of the primary location of hire, with occasional extended travel periods of time, as the project demands change.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/122f7259/apply
#
#
# Requirements
#
# Bachelor’s degree or equivalent experience
# Valid US driver's license, a clean driving record, and 7+ years of driving experience
# Able to demonstrate safe driving in all weather conditions, including snow
# Good mechanical aptitude, basic mechanical skills and general knowledge of operating hand tools, portable power tools, and bench tools
#
# Excellent verbal and written communication skills
# Proficient computer skills, including basic troubleshooting with the ability to utilize proprietary digital tools
# Type 50+ words per minute
# Ability to learn quickly and implement new concepts
# ...
# •	Experience with UX Design: wireframing, theming, prototyping, etc.
# •	Experience with UI Design: branding, layouts, mockups, etc.
# •	Articulate in communicating complex ideas and concepts
# •	Ability to work well with development team and other designers
# •	Insatiable appetite to consume latest trends in Mobile and Web experiences
#
# Desired Skills & Experience
# •	Experience prototyping in Axure
# •	Product design through storyboarding and concept sketches
# •	Proficient with Adobe Creative Suite
# •	Working knowledge of HTML, CSS and JavaScript
#
# You will receive the following benefits:
# •	Medical Insurance
# •	Vision
# •	Flexible spending accounts
# •	Employee assistance program
# •	Free lunches most days of the week
# •	Monthly team events
# •	Fun office environment
# •	Paid vacation
# •	Paid company holidays
#
# To apply for this position, please send a cover letter and resume to: jobs@clinicalresearch.io
# ---
# Job Title: Software Engineer- Dev Ops
# Location: Cambridge, MA
# Date: May  2
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-software-engineer-dev-ops/6879668728.html
#
# compensation: TBD
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Clinical Research IO (CRIO) is a fast-moving start-up company in Kendall Square working to transform the clinical research industry with the latest in cloud and tablet technology. We’re looking for a savvy, detail-oriented Software Engineer to join our Dev Ops team.
# Even in an age of smart-phones, most clinical research today is hand-written on paper and stored in clunky binders. Our system allows doctors and study coordinators to enter that same information into an interactive, easy-to-use tablet and cloud platform.   We accelerate clinical research and make it more efficient - life-saving drugs and medical devices can be analyzed, FDA approved and reach those who need it faster.
#
# As a Software Engineer in our Dev Ops department, you will be responsible for:
#
# -	Managing our infrastructure, both cloud, and in-house
# -	Developing internal applications for customer support, sales, marketing and system administration
# -	Developing API’s, integrating with external vendors, and migrating/managing data
# -	Perform quality assurance manually or through automation (unit test, scripts, etc…)
# -	Ensure our systems are secure and meet regulatory requirements
#
# Requirements:
#
# -	Attention to detail
# -	Java, Linux and MySQL experience
# -	Github, Selenium, Unit Testing Frameworks and Jenkins experience preferable
#
# You'll be working hard for sure, but you'll also learn a tremendous amount and get to experience the joys and challenges of working in a fast-paced and highly entrepreneurial internet company.
#
# If you consider yourself in the top %1, then please send your resume and why you think you would be a good a fit.
#
# Learn more about our company at www.clinicalresearch.io. To apply for this position, please send a cover letter and resume to: jobs@clinicalresearch.io
#
# ---
# Job Title: Lead Full Stack Developer - Travel App
# Location: N/A
# Date: May  1
# Link: https://boston.craigslist.org/gbs/sof/d/boston-lead-full-stack-developer-travel/6879309657.html
#
# compensation: Equity
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Do you love to travel? We're a startup with a big vision to transform the way people plan travel today. Think Spotfiy level of disruption. We think we're really on to something and need a talented developer to join us to make it happen. We're looking for a Boston or New England based Full Stack Developer and/or Technical Co-Founder passionate about solving the travel planning nightmare.
#
# Work directly with the startup founder and UX designer to walk through the process of fully designing and building from scratch a mobile app (web to follow) based on our MVP set of features. If you have the energy, passion, and drive to change the lives of thousands of travelers please read on.
#
# From you:
#
# - You will play an integral role in application development and creative problem solving
#
# - Ability to help us build a modern technical stack and make any 3rd party integrations recommendations
#
# - Experience with Javascript, and common libraries
#
# - Amazing front-end implementation skills using CSS
#
# - Experience with Web Apps
#
# - Able to take role in testing to troubleshoot bugs across browsers and devices
#
# - Willingness to adopt agile mindset and to prioritize to get to MVP launch
#
# - Experience working with an agile design team using Sketch app
#
# - Plus if you've developed scalable, user-friendly front-end services, on social platform before
#
# From us:
#
# - We’d love to see demos of your technical skills and interests in any recent project URLs, GitHub accounts or portfolio links.
#
# - We’d love to tell you more about our exciting and disruptive project with a big vision to transform the travel industry.
#
# - We’ll ask that you sign a non-disclosure and confidentiality agreement for the project.
#
# Students and experienced folks making a career change are welcome. The project should be near flexible full-time hours until the MVP launch. Work can be done remotely but must be available to meet in Boston weekly. We are remote team in Boston, Toronto and London.
#
# Excellent opportunity for someone who wants to create and be part of a game-changing project in the travel industry. This posting is an equity only position, following a successful candidate will have opportunities to grow with the startup. Need to be available outside the typical 9-5 hours to be able to meet with our team.
#
# We look forward to hearing from you!
#
# ---
# Job Title: DevOps Engineer
# Location: BOXBOROUGH
# Date: May  1
# Link: https://boston.craigslist.org/nwb/sof/d/harvard-devops-engineer/6879283391.html
#
# compensation: We offer competitive salary and compensation packages based on experience and qualification. Unfortunately, we do not offer visa sponsorship.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Company
#
# We offer no-nonsense technology solutions in supplier compliance and sustainability. Our software helps businesses collect, manage, automate, and prioritize supplier data through robust reporting and advanced analytics. We value practical, effective solutions to complex business problems and the dedication and follow-through to see those solutions to a successful completion.
# We have a small but growing team in Boxborough, MA. Our office in Suzhou, China enables us to deliver support and project management to customers across the globe. We have bootstrapped for the last few years and are in the process of acquiring several major customers.
#
# Job Description
#
# We are looking to expand its cloud deployment capabilities. You’ll be responsible for all server, tooling, and scalability issues and will be doing a lot of building from the ground up. This is a great opportunity to bring your innovative ideas and apply them at a place where they will have a lot of impact. We are looking for leadership and ownership in DevOps; there are going to be challenges, and we expect you to identify, champion, and commit to effective solutions.
#
# Responsibilities:
# •	Deploy, manage, and scale our Java/Tomcat/MySQL/Elasticsearch web app on Google Compute Engine
# •	Support internal development and testing environments using Vagrant and VirtualBox
# •	Manage CI/CD using Jenkins with a focus on automating database, application, security, monitoring and infrastructure deployments
# •	Manage routers, switches, firewalls, load balancers, VPNs, software deployment, security updates and patches
#
# Requirements:
# •	BS or equivalent experience; minimum 2 years related experience
# •	Hands-on experience with:
# o	Google Cloud Platform or similar cloud service providers
# o	CentOS, OpenBSD
# o	Python, shell scripting, Ansible
# o	Jenkins, Packer, Ant, Maven, Make
# o	Vagrant, VirtualBox
# o	Subversion, Git
# •	Working knowledge:
# o	MySQL, Oracle, PostgreSQL
# o	Service discovery, monitoring, IDS tools
# o	Java, Tomcat, HAProxy, MySQL, Elasticsearch, WebDAV
# o	HTTP, SMTP, DNS, DHCP, TCP/IP, NTP
# o	SSH, OpenVPN, Iptables, PF, TLS, ACME / Let’s Encrypt
# o	Windows Active Directory
# •	Strong troubleshooting instincts and experience
#
# Benefits:
# •	Health and dental insurance
# •	401K
# •	Equity participation
# •	Paid holidays
# •	On-site gym
# •	Team lunches
#
# Unfortunately, we do not offer visa sponsorship.
#
# ---
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')",))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-19-d11a3364137d> in <module>()
#       7     date = job.find('time', {'class': 'result-date'}).text
#       8     link = job.find('a', {'class': 'result-title'}).get('href')
# ----> 9     job_response = requests.get(link)
#      10     job_data = job_response.text
#      11     job_soup = BeautifulSoup(job_data, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')",))

# %% [markdown]
# ## Crawling & Scraping Next Pages

# %%
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        job_no+=1
        print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
# Out:
# Job Title: Seeking iOS/Android Developer
# Location: N/A
# Date: May 25
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-seeking-ios-android-developer/6897232058.html
#
# compensation: $15-$35/hr based on experience/proficiency
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# New Movie Review App Seeking Head Developer
#
# We’re looking for a developer proficient in iOS and Android	(Xcode/java) to work hourly on new features; as well as over see ongoing code for both platforms for smaller/simpler features.
# Our app is simple and straightforward. We have a wonderful and talented developer for our backend/PHP. We’re great people to work with and have big plans for the app, so ideally we're looking for someone long term.
#
# (Open to all applicants but especially interested in POC/Women and individuals in the US time zones)
#
# Looking forward to hearing from you. Please email any resume/samples of your work.
#
# https://itunes.apple.com/us/app/qurator-app/id1450485928?mt=8
# ---
# Job Title: Senior Enterprise Analyst
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-enterprise-analyst/6895801656.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/d3e39f45-97b0-4145-9ef8-e6bcb1c2b3a1?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# About The Team
#
# The Information Systems (IS) team’s mission is to apply information and technology in collaboration with other business units and external stakeholders to improve operating efficiencies and promote innovation across the company. The team plays a key role in leading collaboration with others while creating digital strategies, embracing organizational changes, adopting agile practices, and experimenting with emerging technologies. They do all this while being compliant and secure by enforcing internal policies which are aligned to organizational strategy and vision.
#
# About The Role
#
# The Senior Enterprise Analyst will be a member of the Information Systems team and will be responsible to execute and support IS projects in collaboration with the Business Insights, Information Systems, Marketing, Customer Success, Engineering, and Product teams with direction from the Director of Information Systems. We are looking for a creative problem solver who is passionate about leveraging technology in support of greater operational efficiency for the entire organization. The ideal candidate is analytical, empathetic, customer centric, and thrives in a fast-paced startup environment. This position reports to Director of Information Systems and is located in Boston, MA.
#
# What You'll Do
#
# - Work closely with Business Insights team in providing services related to Data Modeling/Analytics, Business Intelligence, Data Warehousing and Reporting
# - Develop workflow diagrams and functional requirements to communicate with stakeholders
# - Implement and proactively manage the ETL design and development based on MS SQL Server, SSIS, Azure Data Service (Data Factory, Data Lake Storage, Data Warehouse etc.)
# - Communicate effectively to various stakeholders with status updates
# - Identify and cleanse data from external data sources (SalesForce, Marketing Cloud, Google Analytics, Google Adwords, Zendesk, Paypal, Quickbooks etc.)
# - Pursue training and professional development opportunities, strive to continuously build knowledge and skills, stay on top of new trends in Data Modeling, Analytics, ETL and related technologies and share expertise to the team
# - Work closely with marketing team to support/enhance MarTech stack including but not limited to all the integration
# - Prepare and update documentation related to work done
#
# What You'll Bring
#
# - Experience developing data warehousing solutions using SSIS, SQL Server, Azure Data Service
# - Strong ETL experience coupled with Strong SQL knowledge
# - Experience with creating and using SQL procedures, functions and queries
# - Experience with data cleansing, data analysis and profiling
# - Experience creating KPI dashboards and reports using PowerBI from data warehouse
# - Experience with MarTech stack such as Google Analytics, AdWords, Marketing Cloud etc. is a plus
# - Strong communication skills
# - Strong passion for data, analytics, modeling, and relevant technologies
# - Enthusiasm for continuous learning in the always changing information systems landscape
# - Experience working independently and within a team with diverse internal stakeholder groups
# - Ability to work in a fast-paced agile software development environment, handling multiple projects, requests and tasks effectively
#
# Preferred Qualifications/Experience
#
# - BS or equivalent in Computer Science, Information Systems, Data Science or equivalent technical degree
# - 5+ years’ experience in relational and data warehouse database design, optimization and performance; preferably with SSIS, SQL Server
# - Experience developing ETL specifications and mappings to support data integration from external datasources
# - Experience with Azure SQL products and services will be a plus
# - Strong knowledge of referential integrity, triggers, stored procedures and functions
# - Experience with reporting and data visualization application (PowerBI)
# - Understanding of project management and software development lifecycle
# - Experience in maintaining high level of customer satisfaction
# - Possess excellent problem-solving, analytical and time management skills
# - Self-starter, highly motivated, able to shift directions quickly when priorities change
# - Excellent verbal and written communication skills, with ability to present complex ideas in a clear, concise manner
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
#
# ---
# Job Title: Cloud Engineer
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-cloud-engineer/6895791557.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/abcd96c3-3308-4725-9b72-e8856d8e81ac?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home, throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# About The Team
#
# The Information Systems (IS) team’s mission is to apply information and technology in collaboration with other business units and external stakeholders to improve operating efficiencies and promote innovation across the company. The team plays a key role in leading collaboration with others while creating digital strategies, embracing organizational changes, adopting agile practices, and experimenting with emerging technologies. They do all this while being compliant and secure by enforcing internal policies which are aligned to organizational strategy and vision.
#
# About The Role
#
# The Cloud Engineer will be a member of the Information Systems team and will be responsible to implement and support Continuous Delivery and Continuous Integration on all Software Development projects and initiatives within Framework. This role works in collaboration with the Engineering and Product Development teams. We are looking for a person with adequate domain knowledge and hands-on experience in developing and implementing software projects. This person will be responsible for maintaining and improving the CI/CD pipelines in an agile software development environment. This role reports to the Director of Information Systems and is based in Boston, MA
#
# What You'll Do
#
# -Assist the Engineering team to implement and enhance CI/CD
# -Work closely with the Information Systems and Engineering teams to manage and provide help/guidance with CI/CD
# - Proactively manage, maintain, and monitor all CI/CD pipelines
# - Assist and proactively manage the operation of IS backend systems including MS SQL Server, SSIS, Azure Data Service (Data Factory, Data Lake Storage, Data Warehouse etc.)
# - Communicate effectively to various stakeholders with status updates
# - Pursue training and professional development opportunities, strive to continuously build knowledge and skills, stay on top of new trends in CI/CD pipelines, software technologies related to cloud-based deployments and share expertise to the team
# - Prepare and update documentation related to work done
#
# What You'll Bring
#
# - Experience in Continuous Integration/Continuous Delivery techniques, test-driven development, and automated build and testing procedures
# - Passion to engage in continuous learning to ensure knowledge of latest DevOps Techniques, Technologies, and cloud (AWS, Azure) product updates • Passion for coding, problem solving, testing, and maintenance
# - Experience in developing customized code, scripts, modules, procedures using languages such as Python, Java, JavaScript, Bash, and other scripting and development languages
# - Experience working independently and within a team with diverse internal stakeholder groups
# - Ability to work in a fast-paced agile software development environment handling multiple projects, requests, and tasks effectively
#
# Preferred Qualifications/Experience
#
# - BS or equivalent in Computer Science, Engineering, Mathematics or equivalent technical degree •
# 3-5 years’ experience in full stack development using Java, Web Services, Database and microservice development
# - Strong background and experience building and maintaining CI/CD infrastructure automation (Amazon pipeline, Jenkins)
# - Amazon Web Services including EC2, ECS, S3, CloudWatch, Lambda
# - Experience using configuration management tools such as GitHub
# - Experience with Systems Monitoring/Alerting tools (PagerDuty, CloudWatch, DataDog, NewRelic)
# - Experience with container orchestration utilizing docker images (Node.js, Spring Boot applications)
# - Experience with github, maven, scripting (bash, python etc.), databases (postgreSQL, SQL Server)
# - AWS Certifications are definitely a plus for this position
# - Experience with Microsoft SQL Server, SSIS, Power BI and Azure Cloud Service technologies is a plus for this position
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
# ---
# Job Title: Quality Assurance (QA) Engineer
# Location: Boston
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/boston-quality-assurance-qa-engineer/6895749083.html
#
# compensation: Competitive annual salary with full benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# APPLY HERE: https://jobs.lever.co/frameworkhomeownership/9d41b1cf-3b43-4842-9619-0b0740ef5264?lever-origin=applied&lever-source%5B%5D=Craigslist
#
# About the Team
#
# The Engineering team’s mission is to architect and develop innovative mobile and web applications by applying computer science, mathematics, engineering and other disciplines, and collaborating with other business units and external stakeholders. The team plays a vital role in leading collaboration across the company by putting together a tech stack to support platform strategy, which in turn supports various revenue models. They do all this while adopting agile practices and experimenting with emerging technologies for the organization to innovate, as well as remaining compliant and secure and enforcing internal policies which are aligned to organizational strategy and vision.
#
# About the Role
#
# The QA Engineer will develop and launch initiatives that expand our platform and position the company as a leading online resource for our next phase of growth. The person in this role will play a critical role on the Engineering team, creating and implementing QA strategies as well as developing solutions to identified quality problems.
#
# What You'll Do
#
# - Test new Framework platform and software products, and identify deficiencies
# - Develop solutions to identified product problems
# - Plan, create, and manage the overall Quality Planning strategy
# - Provide regular status updates to all assigned sprint tasks in daily stand-up meetings
# - Collaborate and work closely with the product team and scrum master to complete tasks assigned during the sprint planning
# - Identify quality assurance process bottleneck and suggest actions for improvement
# - Analyze, troubleshoot, and resolve production system issues and defects
# - Automate tests with CI/CD pipelines
# - Prepare and present reports with key metrics to Management
# - Develop escalation procedures and policies for different types of issues
# - Understand Framework’s business, customers, and products
#
# What You’ll Bring
#
# - 5 years of experience as a Quality Assurance Engineer
# - Experience working with a variety of different testing techniques such as Mobile App / UI / API Testing, Automated Testing, Test Driven Development Strategies and other
# - Experience with coding using JAVA, Groovy scripts, HTML5, XML
# - Experience with web security technology
# - Experience with software QA tools and processes
# - Understanding of Agile development methodology (Scrum)
# - Demonstrated critical thinking and problem-solving skills
# - Great interpersonal and communication skills; a team player
# - Excellent analytical, organizational, and decision-making skills
# - A sense of ownership and pride in your performance and its impact on the company’s success
# - Ability to thrive in an entrepreneurial and nimble environment; bonus, this excites you
# - Our vision inspires you!
#
# Specific Knowledge Areas
#
# Ready API (SoapUI) and other test automation tools, JSON, JavaScript/Java/Groovy, ReactJS, AWS, PostgreSQL, HTML5, CSS, CSS3, XML, User Interface (UI), Web Services (REST/SOAP), API
#
# Work Environment
#
# This job is in a professional office environment. Routine use of standard office equipment such as computers, phones, photocopiers, and filing cabinets is required. Occasional travel is required, including overnight travel for up to four days at a time.
#
# Physical Demands
#
# This position requires the employee to work in an office environment. It requires the ability to speak and hear in person, over the phone, and in settings where there are groups of people. It requires the ability to travel to a variety of meeting locations including via airplane.
#
# About the Company
#
# Framework is a startup social enterprise built on a simple idea: every homebuyer should have access to unbiased information about the mortgage process and feel knowledgeable about the responsibilities of owning a home, throughout their homeownership journey. We are proudly pro-homeownership and believe it’s a uniquely accessible and powerful way for people to plant and grow seeds of generational wealth. We make it easier for people to do this by providing the tools we believe will lead people into homes that improve their quality of life, giving them the space to grow into their future, and gain value over time. We’re dedicated to helping our customers make decisions with confidence, build wealth in their homes, and protect their investment for generations to come.
#
# As we leverage the power of technology to strengthen communities one homeowner at a time, the individual contributions of our tight-knit team play a vital, daily role in shaping our products and services. Creative thinking, collaboration, and problem solving are at the core of the Framework culture, and we’re seeking team members with drive and creativity to add to the mix.
#
# The position description is a guide to the critical duties and essential functions of the job, not an all-inclusive list of responsibilities, qualifications, physical demands and work environment conditions. Position descriptions are reviewed and revised to meet Framework’s changing needs, at the sole discretion of management.
# ---
# Job Title: Information Security Analyst
# Location: Medford
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/medford-information-security-analyst/6895717080.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job Overview:
# ---
# Job Title: IT AUDIT Manager
# Location: Andover
# Date: May 23
# Link: https://boston.craigslist.org/nwb/sof/d/andover-it-audit-manager/6895466532.html
#
# compensation: $90-$110+benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We have a tremendous opportunity for a driven, self motivated IT/Controls professional who will complete compliance assessments and identify control deficiencies to ensure compliance with regulations, internal controls, policies and procedures; recommend improvements in internal control structure; identify control deficiencies; conduct independent assessments of third parties; conduct assessments for utility regulations, including SOX, GDPR, Data Privacy, Cybersecurity and other federal and state regulations.
#
# Qualifications and Skills
#
# CISA certification a plus
# CRISC certification, CISM a plus
# 1-3 Years of IS Audit Experience
# Understanding of assessing third party service providers and associated risks
# Understanding of SSAE 18 ISAE 3402, SOC 1, SOC 2 reports
#
#
# ---
# Job Title: Research / Mobile / GPS Developer For Transportation / Travel Startup
# Location: N/A
# Date: May 23
# Link: https://boston.craigslist.org/gbs/sof/d/waltham-research-mobile-gps-developer/6895387139.html
#
# compensation: TBD
#
# employment type: contract
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Transportation/travel/tourism early startup at pre-funding stage seeks experienced software / systems developer  / programmer to help design specifications for various research projects leading to development of prototype/POC.  Proprietary research gathered over the past several years serves as basis for unique transportation/travel based service piloted in the Boston area and ultimately rolled out to other cities.
#
# Ideal candidate might have an existing job and could perform pro-bono research / design projects.  We are applying for federal seed funding under the SBIR program.  Upon funding candidate will join as CTO/lead and be paid for the development work required to build the POC/service.  Potential for equity.
#
# Transportation/travel/location related development experience a plus.
#
# Specifications/architecture to be defined include:
#
# 1.	Design innovative technologies, software, systems to be used for in vehicle presentation, labor/resource/demand usage/prediction, data storage/backup and other vehicle/trip related information (ie, iPhone/iPad/Android/GUI/app design, GPS, wireless communication, cloud sharing, cyber security, e-commerce, vehicle systems, BI, etc.)
#
# 2.	Design / customize automated GPS systems to for navigation use for drivers, automate/innovate use of technologies such as GPS (ie, Waze, Google Maps)
#
# 3.	Develop big data processing/predictive analytics/AI systems related to generating and forecasting auto usage from potential customers using technologies such as website or apps
#
# 4.	Design app based scheduling processes for travel / transportation related business
#
# 5.	Define feasibility of various proposed routes as well as logistics (ie, GPS route planning, time of day/day of month travel issues, anticipated traffic congestion, demand forecasting, health/safety factors, coordination with city closures – holidays, construction, accidents, etc.)
#
# 6.	Understand appropriate technologies and issues relating to web and mobile based content management systems, communication systems for data exchange/updates, and data security issues relating to updating customer tracking and in-car activities
#
# 7.	Understand how to scale various service offerings as business scales (hiring needs, website/app traffic increases, incorporation of new technologies or features, partnering with larger travel companies, health/safety issues, etc.)
#
# 8.	Understand how to apply technology developments / lessons learned from a pilot city can apply to new cities
#
# 9.	Design new systems for underserved communities including special apps, podcasting, or
# special technology services (ie, blind, deaf, disabled, elderly)
#
# 10.	Define new technology based in car advertising systems that can be implemented by sponsor companies (ie, dynamic in car display and/or on website ad systems)
#
# Please forward your CV, examples of prior work and a thoughtful cover letter with your interest. Thank you.
# ---
# Job Title: Senior Fullstack Engineer
# Location: N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-fullstack-engineer/6895134115.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our client in Boston, MA is looking for an experienced Senior Fullstack Engineer to join their team. In this role, you will design and develop products and services used by millions of people every day. You will also act as a leader within the team and be involved in large, customer facing projects, architecture, product roadmaps and mentoring of other team members.
#
# Requirements:
# - 5+ years of experience in software development
# - Customer focused mentality
# - Proven proficiency with Javascript
# - Experience working on large scale projects
#
# Relocation and visa sponsorship provided if necessary.
#
# Please upload a copy of your resume detailing relevant work experience for consideration!
# ---
# Job Title: Senior Front End Engineer
# Location: N/A
# Date: May 22
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-front-end-engineer/6895106101.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our client in Boston, the largest home goods website, is looking to add a Senior Front End Software Engineer to their rapidly growing team. Their engineering goal is to make sure each customer has an enjoyable shopping experience.  As a Senior Software Engineer you will be help lead and drive projects, write code that is seen by millions of customers daily, and help make decisions that influence how customers shop online.
#
# Qualifications:
# - 5+ years of Javascript development experience
# - Javascript experience
# - HTML/CSS experience a plus
# - React experience a plus
# - Bachelor of Science in Computer Science or related STEM Field (Applied Math, Computer Engineering, etc.)
#
# This is a full-time, direct-hire position with competitive compensation packages. Relocation assistance and visa sponsorship is provided if needed.
#
# Please provide an updated resume detailing your relevant work and educational experience.
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/6894411295.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSData&utm_campaign=CLBOSData&utm_medium=web
# ---
# Job Title: Product Management Fellow
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellow/6894410723.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSProduct&utm_campaign=CLBOSProduct&utm_medium=web
# ---
# Job Title: Software Engineering Fellow
# Location: N/A
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellow/6894397970.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive internship or job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 130 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job or internship possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are either in university or within 5 years of graduation, and interested in getting the best possible job.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=CLBOSSWE&utm_campaign=CLBOSSWE&utm_medium=web
# ---
# Job Title: Programmer/Developer
# Location: Wrentham
# Date: May 21
# Link: https://boston.craigslist.org/sob/sof/d/wrentham-programmer-developer/6894297679.html
#
# compensation: Up to US$0.00 per year
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Volt has partnered with an electrical manufacturing company to offer this opportunity to someone with a strong background as a Programmer. If interested, please take the time to apply!ProgrammerHours: 8:00 am - 5:00 pmLocation: Foxboro, MADescription:A CAD/CAM Programmer creates drawings and CNC programs using the provided CAD/CAM software. This individual should be proficient with Microsoft Office software (Outlook, Excel, and Word) as well as be able to create new, maintain, and update files from that software. Being able to determine the manufacturing process of a new product from the fixture/holding stage to the finish product is essential for this position.Skills:OutlookExcelWordCreate Drawings & CNC ProgramsExtensive knowledge or C#C, C++, python, bash, batch, VB, .NET, PLC ladder logic, HTML, Javascript, CSS, and build automation (two to three or more of these are needed, not all – but you must have the willingness and aptitude to learn needed technologies and languages quickly)Professional Experience/ Education:Previous Programming experienceAssociates degree in related field minimumWe have a long-standing tradition of developing lasting and mutually beneficial relationships with our employees.  Contact a Volt representative by applying to this posting online for immediate consideration. Submit your resume today!Volt is an Equal Opportunity Employer.
#
# ---
# Job Title: Full time Junior C# .Net Dev - 2 days onsite, 3 days a week from home
# Location: Newbury St Boston
# Date: May 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-time-junior-net-dev-2-days/6893887151.html
#
# compensation: $65,000-$80,000 with healthcare benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# https://thirdeyehealth.net/
#
# Third Eye Health is a national healthcare company providing high quality remote and bedside medical care to acute, post-acute, and senior care organizations.
#
# We are looking for an individual with at least 2 years experience of experience coding C# / SQL for our .NET Core applications.
#
# Experience with swift for iOS mobile app development will put you at the top of the list as you might also be working on our mobile applications that allows physicians to securely send text messages, pictures and stream live video, but to begin with will be writing C# code for our web consult documentation application.
#
# Bachelor Degree in Computer Science required.
#
# You will be working directly with our CTO & one of our developers out of office on Newbury St in Boston two days a week and remotely the other three days.
#
# Please send along a C# code snippet that you've written that is at least 100 lines long.
#
# Job Type: Full-time
#
# Experience:
#
# SQL: 2 years (Required)
# C#: 2 years (Required)
# iOS: 1 year (Preferred)
#
# Education:
#
# Bachelor's (Required)
# ---
# Job Title: Co Founder / Investor Wanted
# Location: Boston Metro Area
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/lynn-co-founder-investor-wanted/6893293370.html
#
# compensation: Equity - Stock Compensation Package
#
# employment type: contract
#
# internship
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Wanted Co-Founder /Investor Wanted to help with a Multimedia Digital Content Entertainment Application product for the 35 million Devoted Weekly Lottery Players in the United States, and then into other countries around the world in the $220 billion dollar industry. I’m the Founder and Creator of LottoGraphs Animated Lottery Videos.
#
# It’s a blend of Computer Animation and Lottery Historical Data. We call it ”LottoMation”.
#
# See it in action and in Real Time At =  https:/www.LottoGraphs.tv
# Create a Free Account then ping me when you complete for a free account upgrade !
#
# We ready to go to Market with all the Massachusetts Lottery Games Completed, which has the highest per capita spend on the lottery in the USA. We need a Marketing Professional who can deliver it to the consumer both B2C and B2B.
# We need a Developer who can complete some easy programming task for other state lottery code modules.
# Click the Executive Summary Button with Due Diligence URL Reference Links for your convenience for more info on the product and industry. https://lottographs.tv/investors-relations/
#
# Pitch to Investors Video  https://www.youtube.com/watch?v=LfQxWSCFuzk
#
# EQUITY - DEVELOPER NEEDED, MUST BE WILLING TO ACCEPT STOCK FOR PAYMENT
# This shows us that you are truly interested in working on this unique project with us. !!
# Must Have Experience with Javascript, HTML5, CSS3, PHP, MySQL
# Mobile App Development, with Android, Apple iOS, Windows Mobile would be a plus
# Ability to help us build a modern technical stack and make 3rd party integrations.
# Able to test and troubleshoot bugs across browsers and devices
# Work can be done remotely but must be available to meet in, Lynn or Boston weekly.
# We’ll ask that you sign a non-disclosure and confidentiality agreement for this project.
#
# If you would like to learn more about the Unique Opportunity, Please Contact me via email first. !
#
# Have a Productive Day Ahead
#
# William B. Lott Jr.
# Founder & Creator of
# LottoGraphs Animated Lottery Videos
# 781-558-7277
# Skype ID = william.lott8
# wlott2004@yahoo.com
# www.LottoGraphs.tv
# Google Us = LottoGraphs
#
#
# ---
# Job Title: BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
# Location: Boston, MA
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/ba-qabusiness-analyst-quality-analyst/6893267113.html
#
# compensation: DOE
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# BA/QA(BUSINESS ANALYST/QUALITY ANALYST) TRAINING & 100% JOB PLACEMENT
#
#
# For more information please call 732 250 3906
#
# Demo Introduction Video: www.youtube.com/watch?v=SHj5bH6VTu8
#
#
# We offer a Combo BA/QA Course where the students can learn the concepts of BA/QA in the same Program with out any additional effort. This also gives the flexibility for the students to choose the best Career option...BA or QA at the end of the course.
#
# 100% JOB PLACEMENT ASSISTANCE RECORD. ALSO SPECIALIZE IN JOBS PLACEMENTS IN NJ,NY as we work mostly with LOCAL CLIENTS in EAST COAST.
#
# We offer detailed ,comprehensive and Job Oriented training in Business Analyst/Quality Analysis with Placement Assistance.
# Flexible timings on Weekdays/Weekends
# Professional guidance for resume preparation and interviews
# Counseling/One-on-one discussion with Trainer to clarify your doubts.
# Flexible timings for the training.
# Aggressive marketing by experienced placement team
# H1b and Green cards sponsorship for deserving candidates
# Training for Certifications and Reimbursement for Certifications on a need basis.
# Professional Training and training material.
# We are currently looking for Citizens/GC holders/OPT/CPT holders/ H1B
# We provide excellent benefits like
#
# Competitive Salary or hourly rates.
# Health Insurance.
# Corporate training opportunities
# Job Placement
# Resume Preparation
# Discussion on Interview Questions
# Job Placement Support
# On Job Support
#
#
# For more information please call 732 250 3906
# QA Testing Course Content
# Introduction to Software Testing
# • What is Software Testing?
#
# Software Development Life cycle
# • Requirements
# • Analysis
# • Design
# • Coding
# • Testing
# • Acceptance
#
# SDLC Models
# • Agile
# • Waterfall model
# • Spiral model
# • V-Model
#
# Testing-Methods
# • White Box Testing
# • Black Box testing
# • Gray Box testing
#
# Types of Testing (Black Box Testing)
# • Build Verification Testing
# • Functional Testing
# • Integration Testing
# • Regression Testing
# • System Testing
# • Acceptance Testing
# • Smoke and Sanity Testing
# • Ad-hoc Testing
# • Exploratory Testing
# • Compatibility Testing
# • Disaster Recovery Resting
# • Load, Volume, Stress and Performance Testing
#
# Testing Life Cycle / Quality Assurance Life Cycle / Software Testing Life Cycle
# • Requirements
# • System study
# • Test plan
# • Test Cases
# • Traceability Matrix
# • Test case execution
# • Defect tracking
# • Test Summary Report
# • User Acceptance Testing
#
# Test Plan
# • Objective
# • Scope
# • Approach
# • Methodologies
# • Deliverables
# • Test environment
# • Schedule and Resources
# • Effort and estimation
# • Entry and Exit criteria
# • Templates
# • Risk
# • Assumption
# • Contingency Plan
# • References
#
# Test Case
# • Test Case Design
# • How to write test cases
# • When to execute test cases
#
# Checklists
# • How to create checklists
# • When to use checklists
#
# Defect tracking
# • Defect life cycle
# • Severity, priority
# • Defect tracking Tool -- Quality Center, Bugzilla and Rational Clear Quest
# • Defect report
# • Defect Tracking Sheet
# • OK for recruiters to contact this job poster.
# • do NOT contact us with unsolicited services or offers
#
#
# •	OK for recruiters to contact this job poster.
# •	do NOT contact us with unsolicited services or offers
#
#
# ---
# Job Title: Autonomous Vehicle Operator | Toyota Research Institute
# Location: cambridge
# Date: May 20
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-autonomous-vehicle-operator/6893248687.html
#
# compensation: Competitive
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/122f7259/apply
#
#
# HireArt is looking to hire a Vehicle Operator to work at Toyota Research Institute’s (TRI) Cambridge location on a contract basis. We're seeking motivated individuals with a passion for technology to join the Driving Operations Team. You'll be responsible for TRI’s autonomous vehicle platforms on various public and private roads obtaining data and fixing technical issues. As a specialist within Driving Operations, you're a valuable contributor, providing necessary feedback to our engineering team aimed at improving groundbreaking automated driving technology.Toyota Research Institute (TRI) is working to build a future where everyone has the freedom to move, engage, and explore with a focus on reducing vehicle collisions, injuries, and fatalities. Join TRI’s mission to improve the quality of human life through advances in artificial intelligence, automated driving, robotics and materials science. TRI is dedicated to building a world of “mobility for all” where everyone, regardless of age or ability, can live in harmony with technology to enjoy a better life. TRI strives  to build a company that helps people thrive, achieve work life balance, and bring their best selves to work. You will have the opportunity to enjoy the best of both worlds ‒ a fun start up environment with brilliant people who enjoy solving tough problems and the financial backing to successfully achieve our goals. If you’re passionate about working with smart people to make cars safer, enable the elderly to age in place, or design alternative fuel sources, TRI is the place for you.Job Responsibilities:
# Maintain Toyota's high standard of safety, inside and outside of the vehicles.
# Consistently demonstrate situational awareness, an understanding of the technology in your care, and a willingness to constantly adjust to changes in the environment.
# Conduct a variety of critical data collection for engineering teams using complex proprietary software and hardware, and communicate through multiple channels.
# Be an ambassador for the technology by communicating expertly and courteously at all times with management, engineers, and members of the public.
# Travel outside of the primary location of hire, with occasional extended travel periods of time, as the project demands change.
#
#
# If you're interested in applying for the role, you can check it out here:
# https://www.hireart.com/jobs/122f7259/apply
#
#
# Requirements
#
# Bachelor’s degree or equivalent experience
# Valid US driver's license, a clean driving record, and 7+ years of driving experience
# Able to demonstrate safe driving in all weather conditions, including snow
# Good mechanical aptitude, basic mechanical skills and general knowledge of operating hand tools, portable power tools, and bench tools
#
# Excellent verbal and written communication skills
# Proficient computer skills, including basic troubleshooting with the ability to utilize proprietary digital tools
# Type 50+ words per minute
# Ability to learn quickly and implement new concepts
# ...
#
# Reference # 8413 - Risa Kahn, Recruiting Manager
#
# Please Apply Here: https://www.ndt.com/job/software-engineer-test-automation
#
# New Dimensions in Technology (NDT)
# Technical and Tech/Business Recruiting Since 1979
#
# ---
# Job Title: Vista Implementation Specialist
# Location: Newton
# Date: Apr 25
# Link: https://boston.craigslist.org/gbs/sof/d/newtonville-vista-implementation/6874340537.html
#
# compensation: Based on experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# ARS Restoration Specialists is recruiting for a Vista Implementation Specialist for it's Newton, MA location! Under the supervision of the Chief Financial Officer the Implementation Specialist is a self-motivated individual whose mission is to fully implement our Vista software and train the team in best practices.
#
# Responsibilities:
# Installing and configuring the Vista system
# Maintaining an extensive understanding of the construction industrys business operation in order to effectively deliver, support and train Vista software modules to team
# Overseeing individual projects for configuration and deployment of additional Vista modules
# Document technical issues, defects, and problems with system or assigned projects
# Maintaining an active role with the various teams within the Finance and Operations group and providing assistance to all staff
# Act as a subject matter expert for questions from staff around accounting integration, construction accounting practices, and financial management of projects
# Assist in identifying issues, enhancement requests, and feature requests from team
#
# Qualifications:
# Direct experience working with Vista (Viewpoint software product)
# Experience as a team lead or consultant for a Vista implementation
# Self-starter with an ability to manage your time and tasks with little oversight, and great attention to detail
# Demonstrated experience in a fast-paced work environment
# Strong interpersonal, organizational, and self-management skills
# Previous experience within the Construction industry is a plus
# Proficient in Advanced Excel is a plus
#
# APPLY NOW
#
#
# ARS Restoration Specialists is an Equal Opportunity Employer that recruits and hires qualified candidates without regard to race, religion, sex, sexual orientation, gender identity, age, national origin, ancestry, citizenship, disability, or veteran status.
# ---
# Job Title: Summer DevOps Internship
# Location: N/A
# Date: May  3
# Link: https://worcester.craigslist.org/sof/d/southborough-summer-devops-internship/6880467247.html
#
# compensation: $15/Hr - 40 hours a week
#
# employment type: full-time
#
# internship
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Job Title: DevOps Engineer Intern
#
# Location(s): Westborough, MA
#
# QPAIR is hiring!
# QPAIR is a Cloud Operations Company and we are looking to hire summer interns.
# Interns will have an opportunity to learn from our expert DevOps engineers and a chance to work with a team of skilled DevOps engineers and software developers, assisting in building features for our CI/CD environment. The interns will be part of an Agile development team learning and following our SDLC and exposed to the latest techniques of building and deploying software into a Cloud environment.
#
# Internship will be for 3-4 months working 40 hours a week.
#
# Desired Skills:
#
# Amazon AWS
#
# Bash / Python / Boto3
#
# Jenkins
#
# AWS services and CLI
#
# Linux and Mac OS
#
# GitHub
#
# Docker
#
# QPAIR is committed to creating a diverse environment and is proud to be an equal opportunity employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability status, age, or veteran status or any other characteristics protected by applicable law. QPAIR is committed to a culturally diverse workforce.
#
# ---
# Job Title: Data Manager
# Location: N/A
# Date: May 15
# Link: https://providence.craigslist.org/sof/d/narragansett-data-manager/6889723644.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Data Manager to work in support of the National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC).
#
# The Data Manager will assist with providing IT support services to the Northeast Fisheries Science Center, working with federal system application developers and database system owners to manage and organize data to ensure data quality, produce data products for presentation, and support applications.  This person will be responsible for managing multiple complex data systems across several Oracle database servers.
#
# The Data Manager will work on-site in one of these locations: Orono ME, Woods Hole MA, Narragansett RI, Milford CT, or Sandy Hook NJ.
#
# Skills and Qualifications
# The Data Manager must:
#
#     Possess proficiency and knowledge of Oracle database systems (11g and 12c).
#     Demonstrate proficiency in SQL.
#     Have a track record of successfully managing large datasets, querying, extracting, and organizing data in useful ways to reduce performance related issues and create data products for end users and system owners.
#     Possess knowledge and skill in reviewing and analyzing data to validate query results.
#     Be capable of performing database updates consistent with the quality control established by the owner.
#     Have experience in providing database support by responding to user questions and resolving problems.
#     Possess demonstrated ability to handle multiple projects and deadlines with flexibility between tasks.
#     Be capable of working as part of a team to understand user requirements.
#     Demonstrate the ability to work with developers and system owners to provide quick resolutions during critical production issues with performance related resolutions.
#     Be able to implement and integrate security standards set by the NOAA/NMFS/ Office of the Chief Information Officer (OCIO) and implemented by NEFSC's DMS Division.
#     Possess excellent written and oral communication skills.
#
# The position is expected to last approximately one year. Pay is commensurate with experience and qualifications, and the position is eligible for the benefits described on the Integrated Statistics website. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=195 or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Medical Equipment Inspection, Troubleshooting and Basic Repair
# Location: N/A
# Date: May  4
# Link: https://southcoast.craigslist.org/sof/d/new-bedford-medical-equipment/6881546089.html
#
# compensation: $600/week
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# BMET: Medical Device Inspection / Biomedical Equipment Analysis.
#
# Medical Equipment Dynamics (MED) is a fast growing business based in New Bedford, MA. We buy idle, decommissioned capital medical equipment to resell. The company sells new, refurbished, used and parts models. More info at https://MED.equipment
#
#
# Medical Equipment Inspection, Troubleshooting and Basic Repair
#
# Responsibilities:
#
#     Assess and perform basic testing of a wide variety of pre-owned medical equipment
#     Document various details such as data, configurations, parameters, software rev, options included, part numbers and other model specific information
#     Determine what parts and accessories should be ordered
#     Replaces parts and perform basic repairs as applicable
#     Deciphering particular variables within a specific model
#     Will assure accurate database entry with a high attention to detail
#
# Requirements:
#
#     Strong demonstrable technical troubleshooting ability
#     Basic working knowledge of electronics
#     Ability to to perform basic inspection of electronic devices
#     Able to troubleshoot and problem-solve equipment and its operation
#     Able to work independently
#     Good documentation skills
#     Computer skills
#
# Qualifications:
#
#     High school diploma, GED or equivalent. Some college or Associate's Degree preferred
#     Research driven, investigative technical skills
# ---
# Job Title: Database Architect
# Location: N/A
# Date: May  5
# Link: https://capecod.craigslist.org/sof/d/woods-hole-database-architect/6881861456.html
#
# compensation: Commensurate with experience and qualifications.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Integrated Statistics is looking for a Database Architect to work in support of the National Oceanic and Atmospheric Administration (NOAA) National Marine Fisheries Service (NMFS) Northeast Fisheries Science Center (NEFSC).  The Northeast Fisheries Science Center (NEFSC) is the research arm of NMFS in the region, planning, developing, and managing a multidisciplinary program of basic and applied research to better understand living marine resources of the Northeast Continental Shelf Ecosystem from the Gulf of Maine to Cape Hatteras, and the habitat quality essential for their existence and continued productivity, and to describe and provide to management, industry, and the public, options for the conservation and utilization of living marine resources, and for the restoration and maintenance of marine environmental quality.
#
# Tasks
# The Data Architect will assist the Data Management Systems (DMS) division, which provides IT support services to the Science Center. The Database Architect will work closely and cooperatively with federal system programmers and application developers to develop and analyze program requirements, and prepare documentation and specifications.
#
# The Database Architect will be responsible for:
#
#     Database architecture, design, and modeling.
#     Maintaining and extending database capabilities to meet business users needs and NMFS standards and best practices.
#     Data Modeling for project specific generation of database and application design documentation.
#     Documenting logical and physical data models and associated entity relationship diagrams.
#
# Qualifications
# The Database Architect must:
#
#     Demonstrate proficiency and extensive knowledge of Oracle database systems.
#     Possess demonstrated, strong programming and development skills using PL/SQL (package, procedures, functions, triggers) and batch coding skills.
#     Have experience in code migration, database change management, and data management in multiple environments and different stages of the development life cycle.
#     Possess the ability to handle multiple projects and deadlines with flexibility between tasks.
#     Be capable of working as part of a team to define and refine user requirements.
#     Have a track record of ensuring performance, security, integrity, and availability of databases.
#     Be able to support application development through integrated project work group meetings, data modeling, code reviews, and system reviews for quality and performance.
#     Demonstrate ability to work with management and developers in providing quick resolutions during critical production issues with performance related resolutions.
#     Possess expert level knowledge and experience in data modeling and database design across all phases of data modeling, from conceptualization to database optimization.
#     Provides database support by coding utilities, responding to user questions, and resolving problems.
#     Emphasize methodology, modeling, and governance while being technologically and politically neutral.
#     Be proficient in logical and physical modeling using tools such as SQLDeveloper Data Modeler, ERWin, or other data system modeling.
#     Possess a thorough understanding of data normalization.
#     Demonstrate proficient in Agile/Scrum methodology, and be familiar with project management software (e.g.,JIRA by Atlassian).
#     Be able toanalyze database performance and positively affect systems via indexing and other methods.
#     Have experience in configuration and deployment of development, test and production environments.
#     Be proficient in designing and implementing data access security via roles or other methods.
#     Be able to implement and integrate data security standards set by the NOAA/NMFS/Office of the Chief Information Officer (OCIO) and implemented by NEFSC’s DMS Division.
#     Possess advanced experience in mapping the systems and interfaces used to manage data, set standards for data management, analyze current state and conceives desired future state, and conceive projects needed to close the gap between current state and future goals.
#     Have a track record of implementing the system development life cycle; software project management approaches; and requirements, design, and test techniques.
#     Demonstrate advanced knowledge and skills necessary to develop and adhere to database standards in design and implementation, and to conceptualize and influence application and interface projects.
#     Be able to analyze database performance and positively affect systems via indexing and other tuning methods.
#
# The position is full-time, and the rate of pay is commensurate with experience and qualifications. The position is eligible for the benefits described on the Integrated Statistics website. The Database Architect is expected to work on-site in Woods Hole, MA. To apply for this position, go to https://jobs.intstats.com/JobDetails.jsp?jobListingId=187 or visit www.integratedstatistics.com, click Employment Opportunities, click the job name and click the Apply Here link.
#
# Integrated Statistics is an equal opportunity employer and will not discriminate against any employee or applicant on the basis of age, color, disability, gender, national origin, race, religion, gender identity, sexual orientation, veteran status, or any classification protected by federal, state, or local law. Consistent with its obligations under federal law, Integrated Statistics is committed to taking affirmative action to employ and advance in employment qualified women, minorities, disabled individuals, special disabled veterans, veterans of the Vietnam era, and other eligible veterans. For assistance with accessibility of applications, posters, forms, and/or documents, please email the Integrated Statistics office.
# ---
# Job Title: Business Analyst - UCONN
# Location: N/A
# Date: Apr 25
# Link: https://hartford.craigslist.org/sof/d/putnam-business-analyst-uconn/6874669025.html
#
# compensation: $50-65/hr
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# UCONN has an opening for a solid Business Analyst capable of collaborating with both the functional and technical teams to work on-site at the UCONN campus in Storrs, CT.  The position is for one year.  Local candidates are preferred as they will have a face-to-face interview in Storrs.
#
# Requirements:
# •         Experience with data marts/data warehouses
# •         HR knowledge (preferable PeopleSoft but not required)
# •         Payroll Knowledge (preferable PeopleSoft but not required)
# •         Not a PeopleSoft Developer
#
# ---
# Total Jobs: 81

# %% [markdown]
# ## Saving Output to CSV File

# %%
import pandas as pd
# Create a dictionary
d = {'key':'value'}
print(d)

# Update the dictionary
d['new key'] = 'new value'
print(d)
# Out:
# {'key': 'value'}
# {'key': 'value', 'new key': 'new value'}

# %%
npo_jobs = {}
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        
        job_no+=1
        npo_jobs[job_no] = [title, location, date, link, job_attributes, job_description]
        
        
#print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', 
#link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
        
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs, orient = 'index', columns = ['Job Title','Location','Date', 
                                                                            'Link', 'Job Attributes', 
                                                                            'Job Description'])


npo_jobs_df.head(10)

npo_jobs_df.to_csv('npo_jobs.csv')
# Out:
# Total Jobs: 81
